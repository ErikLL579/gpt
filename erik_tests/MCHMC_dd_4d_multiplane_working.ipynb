# %%
import gpt as g
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec
from itertools import permutations

import scipy
import math
from scipy import special as sp
import time
# Out:
# SharedMemoryNone: SharedMemoryAllocate 1073741824 GPU implementation
# 0SharedMemoryNone:  SharedMemoryNone.cc acceleratorAllocDevice 1073741824bytes at 0x300000000 for comms buffers
#
# __|__|__|__|__|__|__|__|__|__|__|__|__|__|__
# __|__|__|__|__|__|__|__|__|__|__|__|__|__|__
# __|_ |  |  |  |  |  |  |  |  |  |  |  | _|__
# __|_                                    _|__
# __|_   GGGG    RRRR    III    DDDD      _|__
# __|_  G        R   R    I     D   D     _|__
# __|_  G        R   R    I     D    D    _|__
# __|_  G  GG    RRRR     I     D    D    _|__
# __|_  G   G    R  R     I     D   D     _|__
# __|_   GGGG    R   R   III    DDDD      _|__
# __|_                                    _|__
# __|__|__|__|__|__|__|__|__|__|__|__|__|__|__
# __|__|__|__|__|__|__|__|__|__|__|__|__|__|__
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |
#
#
# Copyright (C) 2015 Peter Boyle, Azusa Yamaguchi, Guido Cossu, Antonin Portelli and other authors
#
# This program is free software; you can redistribute it and/or modify
# it under the terms of the GNU General Public License as published by
# the Free Software Foundation; either version 2 of the License, or
# (at your option) any later version.
#
# This program is distributed in the hope that it will be useful,
# but WITHOUT ANY WARRANTY; without even the implied warranty of
# MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.  See the
# GNU General Public License for more details.
# Current Grid git commit hash=e138258129faed5cb12fc0e5bbf829f69c6a2a3d: (HEAD -> feature/gpt, origin/feature/gpt, origin/HEAD) uncommited changes
#
# Grid : Message : ================================================
# Grid : Message : MPI is initialised and logging filters activated
# Grid : Message : ================================================
# Grid : Message : This rank is running on host Eriks-MacBook-Pro-6.local
# Grid : Message : Requested 1073741824 byte stencil comms buffers
# Grid : Message : MemoryManager::Init() setting up
# Grid : Message : MemoryManager::Init() cache pool for recent host   allocations: SMALL 8 LARGE 2 HUGE 0
# Grid : Message : MemoryManager::Init() cache pool for recent device allocations: SMALL 16 LARGE 8 Huge 0
# Grid : Message : MemoryManager::Init() cache pool for recent shared allocations: SMALL 16 LARGE 8 Huge 0
# Grid : Message : MemoryManager::Init() Unified memory space
#
# =============================================
#               Initialized GPT
#      Copyright (C) 2020 Christoph Lehner
# =============================================

# %%
class Jackknife:
    def __init__( self, len_data, binsize ):
        self.binsize = binsize
        self.nbins = math.floor( len_data/self.binsize )
        self.N = self.binsize * self.nbins
        self.jack_avg = []
        self.est = 0
        self.var_est = 0

    def set( self, func, list_of_data ):
        for i in range( self.nbins ):
            self.jack_avg.append( func( i, self.binsize, list_of_data ) )

    def do_it( self ):
        for i in range( 0, self.nbins ):
            self.est += self.jack_avg[i]
        self.est /= self.nbins

        for i in range( 0, self.nbins ):
            self.var_est += ( self.jack_avg[i] - self.est )**2
        self.var_est /= self.nbins
        self.var_est *= self.nbins -1

    def mean( self ):
        return self.est

    def var( self ):
        return self.var_est

    def err( self ):
        return np.sqrt(self.var_est)

def simple_mean(i, binsize, np_data):
    resmpld = np.delete(np_data, np.s_[i*binsize:(i+1)*binsize])
    return np.mean(resmpld)

def format_print(cen, err):
    for i in range(-50, 50):
        if 10**(-i+1)>=err>10**(-i):
            tmp=err*10**(i+1)
            return '{num:.{width}f}'.format(num=cen, width=i+1)+'('+str(round(tmp))+')'

def format_print_w_exact(exact, cen, err):
    for i in range(-50, 50):
        if 10**(-i+1)>=err>10**(-i):
            tmp=err*10**(i+1)
            return '{num:.{width}f}'.format(num=cen, width=i+1)+'('+str(round(tmp))+')'+': '+'{num:.{width}f}'.format(num=(exact-cen)/err, width=i+1)+' sigma'

# %%
def autocorrelation2(samples, separation, max_separation, binsize):
    mean = np.mean(samples)
    ACF = []
    err = []
    t = -1
    nskip = int(0)
    #binsize = 50
    
    for i in range(int(max_separation / separation)):
        t += separation
        temp = []
        
        for i in range(np.size(samples)-t):
            temp.append((samples[i+t] - mean) * (samples[i] - mean))
        
        N2 = np.size(temp)
    
        jk = Jackknife( N2-nskip, binsize )
        jk.set( simple_mean, temp )
        jk.do_it()
        
        ACF.append(np.mean(temp))
        err.append(jk.err())
    
    x = np.arange(1, np.size(ACF))
    for i in x:
        ACF[i] /= ACF[0]
        err[i] /= ACF[0]
        
    err[0] = 0.
    ACF[0] = 1.
    
    
    return ACF, err

# %%
size = 8
grid = g.grid([size, size, size, size], g.double)
rng = g.random(str(time.time()))

U = g.qcd.gauge.unit(grid)
rng.normal_element(U)
# Out:
# GPT :       1.271143 s : Initializing gpt.random(1753194381.268245,vectorized_ranlux24_389_64) took 0.000205994 s
# [lattice(ot_matrix_su_n_fundamental_group(3),double),
#  lattice(ot_matrix_su_n_fundamental_group(3),double),
#  lattice(ot_matrix_su_n_fundamental_group(3),double),
#  lattice(ot_matrix_su_n_fundamental_group(3),double)]

# %%
action_gauge = g.qcd.gauge.action.wilson(7.0)

metro = g.algorithms.markov.metropolis(rng)
inv = g.algorithms.inverter
sympl = g.algorithms.integrator.symplectic

log = sympl.log()
pure_gauge = True

# %%
# thermalize lattice first
beta = g.default.get_float("--beta", 7.0)
seed = g.default.get("--seed", "hmc-pure-gauge")
ntherm = g.default.get_int("--ntherm", 10)
n = g.default.get_int("--n", 200)
nwrite = g.default.get_int("--nwrite", 10)
g.default.set_verbose("omf4")

# conjugate momenta
mom = g.group.cartesian(U)

# Log
g.message(f"Lattice = {grid.fdimensions}")
g.message("Actions:")
# action for conj. momenta
a0 = g.qcd.scalar.action.mass_term()
g.message(f" - {a0.__name__}")

# wilson action 
a1 = g.qcd.gauge.action.wilson(beta)
g.message(f" - {a1.__name__}")
    
    
def hamiltonian():
    return a0(mom) + a1(U) 

# molecular dynamics
sympl = g.algorithms.integrator.symplectic
    
iphmc = sympl.update_p(mom, lambda: a1.gradient(U, U))
iqhmc = sympl.update_q(U, lambda: a0.gradient(mom, mom))

# integrator
mdint_hmc = sympl.leap_frog(50, iphmc, iqhmc)
#g.message(f"Integration scheme:\n{mdint}")
    
# metropolis
metro = g.algorithms.markov.metropolis(rng)
    
# MD units
tau = 1.0
g.message(f"tau = {tau} MD units")

def hmc(tau, mom):
    rng.normal_element(mom)
    accrej = metro(U)
    h0 = hamiltonian()
    mdint_hmc(tau)
    h1 = hamiltonian()
    return [accrej(h1, h0), h1 - h0]


# thermalization
for i in range(1, 20):
    h = []
    timer = g.timer("hmc")
    for _ in range(ntherm // 10):
        timer("trajectory")
        h += [hmc(tau, mom)]
    h = np.array(h)
    timer()
    g.message(f"{i*10} % of thermalization completed")
    g.message(timer)
    g.message(
        f"Plaquette = {g.qcd.gauge.plaquette(U)}, Acceptance = {np.mean(h[:,0]):.2f}, |dH| = {np.mean(np.abs(h[:,1])):.4e}"
    )


start = time.time()

# production
history = []
plaq = []


wf_energyHMC = []
for i in range(50):
    history += [hmc(tau, mom)]
    P = g.qcd.gauge.plaquette(U)
    plaq.append(P)
    g.message(f"Trajectory {i}, P={P}")
    #if i % nwrite == 0:
    #    g.save(f"ckpoint_lat.{seed}.{i}", U, g.format.nersc())

    """
    if i % 5 == 0:
        t = 0.0
        eps = 0.05
        U_wf = g.copy(U)
        
        for i in range(160): # t = 8
            U_wf = g.qcd.gauge.smear.wilson_flow(U_wf, epsilon=eps)

        E = g.qcd.gauge.energy_density(U_wf)
        wf_energyHMC.append(E)
    """


end = time.time()
print("time taken = ", end - start)

history = np.array(history)
g.message(f"Acceptance rate = {np.mean(history[:,0]):.2f}")
g.message(f"<|dH|> = {np.mean(np.abs(history[:,1])):.4e}")
# Out:
# GPT :       1.705517 s : Lattice = [8, 8, 8, 8]
# GPT :       1.707190 s : Actions:
# GPT :       1.707887 s :  - mass_term(m^-1 = 1.0)
# GPT :       1.708485 s :  - wilson(7.0)
# GPT :       1.709831 s : tau = 1.0 MD units
# GPT :       2.378043 s : 10 % of thermalization completed
# GPT :       2.378360 s : hmc:
#                        : trajectory           6.67e-01 s (= 100.00 %); time/s = 6.67e-01/6.67e-01/6.67e-01 (min/max/avg)
# GPT :       2.378996 s : Plaquette = 0.2928928082812793, Acceptance = 1.00, |dH| = 1.2825e+01
# GPT :       3.015387 s : 20 % of thermalization completed
# GPT :       3.015709 s : hmc:
#                        : trajectory           6.36e-01 s (= 100.00 %); time/s = 6.36e-01/6.36e-01/6.36e-01 (min/max/avg)
# GPT :       3.016460 s : Plaquette = 0.4004302813468106, Acceptance = 1.00, |dH| = 6.8511e+00
# GPT :       3.644187 s : 30 % of thermalization completed
# GPT :       3.644490 s : hmc:
#                        : trajectory           6.28e-01 s (= 100.00 %); time/s = 6.28e-01/6.28e-01/6.28e-01 (min/max/avg)
# GPT :       3.645190 s : Plaquette = 0.4635426570887055, Acceptance = 1.00, |dH| = 4.0886e+00
# GPT :       4.304998 s : 40 % of thermalization completed
# GPT :       4.305292 s : hmc:
#                        : trajectory           6.60e-01 s (= 100.00 %); time/s = 6.60e-01/6.60e-01/6.60e-01 (min/max/avg)
# GPT :       4.306173 s : Plaquette = 0.5101542299019525, Acceptance = 1.00, |dH| = 3.1668e+00
# GPT :       4.953318 s : 50 % of thermalization completed
# GPT :       4.953625 s : hmc:
#                        : trajectory           6.47e-01 s (= 100.00 %); time/s = 6.47e-01/6.47e-01/6.47e-01 (min/max/avg)
# GPT :       4.954258 s : Plaquette = 0.5432201077777826, Acceptance = 1.00, |dH| = 2.1511e+00
# GPT :       5.594219 s : 60 % of thermalization completed
# GPT :       5.594499 s : hmc:
#                        : trajectory           6.40e-01 s (= 100.00 %); time/s = 6.40e-01/6.40e-01/6.40e-01 (min/max/avg)
# GPT :       5.595216 s : Plaquette = 0.5680762266579976, Acceptance = 1.00, |dH| = 1.4415e+00
# GPT :       6.240133 s : 70 % of thermalization completed
# GPT :       6.240418 s : hmc:
#                        : trajectory           6.45e-01 s (= 100.00 %); time/s = 6.45e-01/6.45e-01/6.45e-01 (min/max/avg)
# GPT :       6.241119 s : Plaquette = 0.5889207686169428, Acceptance = 1.00, |dH| = 1.4110e+00
# GPT :       6.891547 s : 80 % of thermalization completed
# GPT :       6.891850 s : hmc:
#                        : trajectory           6.50e-01 s (= 100.00 %); time/s = 6.50e-01/6.50e-01/6.50e-01 (min/max/avg)
# GPT :       6.892550 s : Plaquette = 0.6066123816513441, Acceptance = 1.00, |dH| = 1.1819e+00
# GPT :       7.541420 s : 90 % of thermalization completed
# GPT :       7.541766 s : hmc:
#                        : trajectory           6.49e-01 s (= 100.00 %); time/s = 6.49e-01/6.49e-01/6.49e-01 (min/max/avg)
# GPT :       7.542550 s : Plaquette = 0.6187562425172098, Acceptance = 1.00, |dH| = 9.6571e-01
# GPT :       8.216957 s : 100 % of thermalization completed
# GPT :       8.217272 s : hmc:
#                        : trajectory           6.74e-01 s (= 100.00 %); time/s = 6.74e-01/6.74e-01/6.74e-01 (min/max/avg)
# GPT :       8.217943 s : Plaquette = 0.6305812068006766, Acceptance = 1.00, |dH| = 6.2171e-01
# GPT :       8.862873 s : 110 % of thermalization completed
# GPT :       8.863180 s : hmc:
#                        : trajectory           6.45e-01 s (= 100.00 %); time/s = 6.45e-01/6.45e-01/6.45e-01 (min/max/avg)
# GPT :       8.863908 s : Plaquette = 0.6369154451106872, Acceptance = 1.00, |dH| = 4.4042e-01
# GPT :       9.526715 s : 120 % of thermalization completed
# GPT :       9.527016 s : hmc:
#                        : trajectory           6.63e-01 s (= 100.00 %); time/s = 6.63e-01/6.63e-01/6.63e-01 (min/max/avg)
# GPT :       9.527671 s : Plaquette = 0.645102867990949, Acceptance = 1.00, |dH| = 6.4533e-01
# GPT :      10.175631 s : 130 % of thermalization completed
# GPT :      10.175926 s : hmc:
#                        : trajectory           6.48e-01 s (= 100.00 %); time/s = 6.48e-01/6.48e-01/6.48e-01 (min/max/avg)
# GPT :      10.176534 s : Plaquette = 0.6493668479348693, Acceptance = 1.00, |dH| = 3.7796e-01
# GPT :      10.819835 s : 140 % of thermalization completed
# GPT :      10.820130 s : hmc:
#                        : trajectory           6.43e-01 s (= 100.00 %); time/s = 6.43e-01/6.43e-01/6.43e-01 (min/max/avg)
# GPT :      10.820832 s : Plaquette = 0.6547652074955013, Acceptance = 1.00, |dH| = 3.5956e-01
# GPT :      11.475480 s : 150 % of thermalization completed
# GPT :      11.475824 s : hmc:
#                        : trajectory           6.55e-01 s (= 100.00 %); time/s = 6.55e-01/6.55e-01/6.55e-01 (min/max/avg)
# GPT :      11.476652 s : Plaquette = 0.6568648109912331, Acceptance = 1.00, |dH| = 2.7854e-01
# GPT :      12.142014 s : 160 % of thermalization completed
# GPT :      12.142314 s : hmc:
#                        : trajectory           6.65e-01 s (= 100.00 %); time/s = 6.65e-01/6.65e-01/6.65e-01 (min/max/avg)
# GPT :      12.143012 s : Plaquette = 0.6597593682153776, Acceptance = 1.00, |dH| = 2.2353e-01
# GPT :      12.804303 s : 170 % of thermalization completed
# GPT :      12.804579 s : hmc:
#                        : trajectory           6.61e-01 s (= 100.00 %); time/s = 6.61e-01/6.61e-01/6.61e-01 (min/max/avg)
# GPT :      12.805252 s : Plaquette = 0.6586143961575113, Acceptance = 1.00, |dH| = 2.4270e-01
# GPT :      13.466485 s : 180 % of thermalization completed
# GPT :      13.466801 s : hmc:
#                        : trajectory           6.61e-01 s (= 100.00 %); time/s = 6.61e-01/6.61e-01/6.61e-01 (min/max/avg)
# GPT :      13.467635 s : Plaquette = 0.6599285549282621, Acceptance = 1.00, |dH| = 1.1436e-01
# GPT :      14.104590 s : 190 % of thermalization completed
# GPT :      14.104897 s : hmc:
#                        : trajectory           6.37e-01 s (= 100.00 %); time/s = 6.37e-01/6.37e-01/6.37e-01 (min/max/avg)
# GPT :      14.105650 s : Plaquette = 0.6608404490059702, Acceptance = 1.00, |dH| = 2.1016e-03
# GPT :      14.749158 s : Trajectory 0, P=0.6598180350266167
# GPT :      15.400110 s : Trajectory 1, P=0.6609551775026171
# GPT :      16.033185 s : Trajectory 2, P=0.6645885110134516
# GPT :      16.661508 s : Trajectory 3, P=0.6672548563800468
# GPT :      17.289892 s : Trajectory 4, P=0.6672548563800468
# GPT :      17.937132 s : Trajectory 5, P=0.6645516927104496
# GPT :      18.569671 s : Trajectory 6, P=0.665691709212623
# GPT :      19.218028 s : Trajectory 7, P=0.6663962028200461
# GPT :      19.846709 s : Trajectory 8, P=0.6670355705773114
# GPT :      20.478370 s : Trajectory 9, P=0.6668324797501904
# GPT :      21.104925 s : Trajectory 10, P=0.6670482580844005
# GPT :      21.739066 s : Trajectory 11, P=0.6680506595337999
# GPT :      22.356455 s : Trajectory 12, P=0.6677293026649475
# GPT :      22.986649 s : Trajectory 13, P=0.6711452345899959
# GPT :      23.621081 s : Trajectory 14, P=0.6699740061772235
# GPT :      24.251113 s : Trajectory 15, P=0.6699132159248152
# GPT :      24.877896 s : Trajectory 16, P=0.6699046510588939
# GPT :      25.499624 s : Trajectory 17, P=0.6699046510588939
# GPT :      26.135081 s : Trajectory 18, P=0.6675836484828941
# GPT :      26.811859 s : Trajectory 19, P=0.6667870926755186
# GPT :      27.458125 s : Trajectory 20, P=0.6685118693660236
# GPT :      28.116261 s : Trajectory 21, P=0.6670918231008492
# GPT :      28.764299 s : Trajectory 22, P=0.6701021162549634
# GPT :      29.471485 s : Trajectory 23, P=0.6675742374786369
# GPT :      30.133448 s : Trajectory 24, P=0.6674849163336933
# GPT :      30.792449 s : Trajectory 25, P=0.6685003314497965
# GPT :      31.427000 s : Trajectory 26, P=0.6687312884658317
# GPT :      32.061104 s : Trajectory 27, P=0.6707560081131331
# GPT :      32.694204 s : Trajectory 28, P=0.6706900856937378
# GPT :      33.323370 s : Trajectory 29, P=0.6702448216077831
# GPT :      33.986954 s : Trajectory 30, P=0.6714258919141255
# GPT :      34.646822 s : Trajectory 31, P=0.6696109894102507
# GPT :      35.276638 s : Trajectory 32, P=0.6678670132391958
# GPT :      35.911021 s : Trajectory 33, P=0.668149175681977
# GPT :      36.522061 s : Trajectory 34, P=0.6706603777273111
# GPT :      37.143935 s : Trajectory 35, P=0.6710259794402594
# GPT :      37.782245 s : Trajectory 36, P=0.6701969483787393
# GPT :      38.427618 s : Trajectory 37, P=0.6692931315471462
# GPT :      39.054438 s : Trajectory 38, P=0.6685264362496013
# GPT :      39.697794 s : Trajectory 39, P=0.6680716730699997
# GPT :      40.322013 s : Trajectory 40, P=0.6679346286696132
# GPT :      40.961114 s : Trajectory 41, P=0.6705400776089688
# GPT :      41.597263 s : Trajectory 42, P=0.6702576414205826
# GPT :      42.217999 s : Trajectory 43, P=0.6700832467839785
# GPT :      42.876215 s : Trajectory 44, P=0.6700832467839785
# GPT :      43.510519 s : Trajectory 45, P=0.670359899419977
# GPT :      44.148723 s : Trajectory 46, P=0.6717962179590642
# GPT :      44.796181 s : Trajectory 47, P=0.6698924479114178
# GPT :      45.414367 s : Trajectory 48, P=0.671994667454248
# GPT :      46.042784 s : Trajectory 49, P=0.6704248133194546
# time taken =  31.937297821044922
# GPT :      46.043265 s : Acceptance rate = 0.94
# GPT :      46.043519 s : <|dH|> = 1.4120e-01

# %%
W = g.copy(U)

# %%
                                        # domain to be updated. even = False => odd
def freeze_connecting_links(block_size, even_coords, odd_coords, even = True):
    domain_even = g.domain.even_odd_blocks(grid, [block_size for i in range(grid.nd)], g.even)
    domain_odd = g.domain.even_odd_blocks(grid, [block_size for i in range(grid.nd)], g.odd)

    if even:
        active_coords = even_coords
        frozen_coords = odd_coords
        domain_parity = domain_even
    else:
        active_coords = odd_coords
        frozen_coords = even_coords
        domain_parity = domain_odd
    
    def find_links_to_freeze():
        vol = block_size ** grid.nd
        links = []

        border_domains = []
        boundary_points = np.array([[0,0,0,0]], dtype=np.int32)
        for i in range(domain_parity.number_of_local_blocks//2 ) :
            domain =  active_coords[ vol*i : vol*(i+1) ] # pick out the coords in adjacent domains
            if np.any(domain[0] == 0) or np.any(domain[-1] == size-1):
                border_domains.append( i )
                boundary_points = np.concatenate(( boundary_points, domain )) # all points in the boundary domains are added 

        x = [1, size-1] + [0 for i in range(grid.nd - 2)]
        perms = np.unique(list(permutations(x)), axis=0)
        
        
        # removing loop over all domains here
        #for j in border_domains:
        j = border_domains[-1]
        domain = active_coords[ vol*j : vol*(j+1) ]
        max_vals = domain[-1]
            
        for k in domain:
            if np.any(k == max_vals): # really only need forward ends
                for l in perms:
                    if (boundary_points == (k + np.asarray(l, dtype=np.int32) ) % size ).all(axis=1).any():
                        links.append( [k , np.where(np.asarray(l) == 1)[0][0]])
        
        j = border_domains[-1]
        domain = active_coords[ vol*j : vol*(j+1) ]

        domain_entries = []
        for i in range(len(links)):
            domain_entries.append( [np.where((domain == links[i][0]).all(axis=1))[0], links[-i][1]] )

        frozen_links = []
        
        for i in range(domain_parity.number_of_local_blocks//2 ) :
            domain =  active_coords[ vol*i : vol*(i+1) ]
            for l in domain_entries:
                frozen_links.append( [domain[l[0]], l[1]])
        
        return frozen_links
    
    def freeze_opposite_parity_blocks():
        return frozen_coords
        
    def link_masks():
        frozen_sites = freeze_opposite_parity_blocks()
        frozen_links = find_links_to_freeze()

        mask = g.qcd.gauge.unit(grid)   
        
        for i in frozen_sites:
            for mu in range(grid.nd):
                mask[mu][i] = 0.
    
        for j in frozen_links:
            mask[j[1]][j[0]] = 0.
        

        return mask

    return link_masks()

# %%
def coordinate_mask(block_size, even_coords, odd_coords, even = True):
    vol = block_size ** grid.nd
    
    if even:
        conjugate_site_locations = even_coords
    else:
        conjugate_site_locations = odd_coords

    blocks_per_line = size // block_size // 2 # this should still be good (but check here)
    skip = vol * blocks_per_line # need to be careful about the order in which blocks appear in the domain
    
    idx  = np.arange(conjugate_site_locations.shape[0]) 
    mask11 = ((idx // skip) % 2) == 1 # create mask to keep 4, skip 4, keep 4 etc

    coord_mask = conjugate_site_locations[mask11] # apply mask 

    mask = g.qcd.gauge.unit(grid) 
        
    for i in coord_mask:
        for mu in range(grid.nd):
            mask[mu][i] = 0.

    return mask
    
def momentum_mask(block_size, even_coords, odd_coords, even = True):
    vol = block_size ** grid.nd
    
    if even:
        conjugate_site_locations = even_coords
    else:
        conjugate_site_locations = odd_coords
    
    blocks_per_line = size // block_size // 2
    skip = vol * blocks_per_line
    
    idx  = np.arange(conjugate_site_locations.shape[0])
    mask11 = ((idx // skip) % 2) == 0
    
    mom_mask = conjugate_site_locations[mask11]
    
    mask = g.qcd.gauge.unit(grid)   
        
    for i in mom_mask:
        for mu in range(grid.nd):
            mask[mu][i] = 0.
        
    return mask

# %%
def MC_Ham(U):
    return action_gauge(U)

# %%
def gauge_force_coord_update(frozen_links, momenta_mask, block_size):
    # calculate gradients
    V = action_gauge.gradient(U, U)
    
    # shift to other domain ; should be done in 2 of 3 directions, and these can al be the same
    for i in [2,3]:
        for mu in range(grid.nd):
            V[mu] = g.cshift(V[mu], i, block_size)

    for mu in range(grid.nd):
        V[mu] @= g(V[mu] * frozen_links[mu] * momenta_mask[mu]) # also need mask to block the other active domain!!!
    
    #print(V)
    
    x = log(lambda: V , "gauge")()
    
    return x

def gauge_force_mom_update(frozen_links, coordinate_mask, block_size):

     # calculate gradients
    V = action_gauge.gradient(U, U)
    
    # shift to other domain
    for i in [2,3]:
        for mu in range(grid.nd):
            V[mu] = g.cshift(V[mu], i, -block_size)
        
    for mu in range(grid.nd):
        V[mu] @= g(V[mu] * frozen_links[mu] * coordinate_mask[mu])
    
    
    x = log(lambda: V , "gauge")()
    
    return x

block_size = 4

even_coords = g.domain.even_odd_blocks(grid, [block_size for i in range(grid.nd)], g.even).gcoor
odd_coords = g.domain.even_odd_blocks(grid, [block_size for i in range(grid.nd)], g.odd).gcoor


# try swapping coords
for i in range(len(even_coords)):
    x = even_coords[i].copy()
    even_coords[i][1] = x[3]
    even_coords[i][3] = x[1]

    y = odd_coords[i].copy()
    odd_coords[i][1] = y[3]
    odd_coords[i][3] = y[1]

    even_coords[i][0] = x[2]
    even_coords[i][2] = x[0]
    
    odd_coords[i][0] = y[2]
    odd_coords[i][2] = y[0]


even = False
frozen224 = freeze_connecting_links(block_size, even_coords, odd_coords, even)
coord_mask4 = coordinate_mask(block_size, even_coords, odd_coords, even)
mom_mask4 = momentum_mask(block_size, even_coords, odd_coords, even)


iq_14 = sympl.update_q(
    U, log(lambda: gauge_force_coord_update(frozen224, mom_mask4, block_size), "gauge_force_coord_update")
)

iq_24 = sympl.update_p(
    U, log(lambda: gauge_force_mom_update(frozen224, coord_mask4, block_size), "gauge_force_mom_update")
)

# integrator
mdint__4 = sympl.leap_frog(40, iq_14, iq_24)

# %%
energies2 = [MC_Ham(U)]

for i in range(10):
    mdint__4(tau)
    mdint__4(-tau) # something is still wrong
    energies2.append(MC_Ham(U))
    
    print("traj = ", i , "ham = ", energies2[-1])
# Out:
# traj =  0 ham =  57177.08547011657
# traj =  1 ham =  57177.0854701168
# traj =  2 ham =  57177.08547011701
# traj =  3 ham =  57177.08547011721
# traj =  4 ham =  57177.08547011741
# traj =  5 ham =  57177.08547011764
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 4
#       1 energies2 = [MC_Ham(U)]
#       3 for i in range(10):
# ----> 4     mdint__4(tau)
#       5     mdint__4(-tau) # something is still wrong
#       6     energies2.append(MC_Ham(U))
#
# File ~/Documents/Physics/lattice/gpt/lib/gpt/algorithms/integrator/symplectic/base.py:118, in symplectic_base.__call__(self, tau)
#     113         if verbose:
#     114             gpt.message(
#     115                 f"{self.__name__} on step {i}/{n}: {op[-1]}({step * tau}, {direction})"
#     116             )
# --> 118         op[1](step * tau, direction)
#     120 if verbose:
#     121     time()
#
# File ~/Documents/Physics/lattice/gpt/lib/gpt/algorithms/integrator/euler.py:36, in euler.__call__(self, eps, direction)
#      34 funcs = gpt.core.util.to_list(self.func())
#      35 for i in range(len(funcs)):
# ---> 36     self.dst[i] @= gpt.group.compose(gpt.eval(self.sign * eps * funcs[i]), self.dst[i])
#
# File ~/Documents/Physics/lattice/gpt/lib/gpt/core/group/operation.py:72, in compose(left, right)
#      68 right_type_cartesian = right_type.cartesian()
#      70 if left_type.__name__ == right_type_cartesian.__name__:
#      71     dst = [
# ---> 72         right_type.compose(projected_convert(l, right_type), r) for l, r in zip(left, right)
#      73     ]
#      75 elif left_type_cartesian.__name__ == right_type.__name__:
#      76     dst = [
#      77         left_type.compose(l, projected_convert(r, left_type)) for l, r in zip(left, right)
#      78     ]
#
# File ~/Documents/Physics/lattice/gpt/lib/gpt/core/group/operation.py:39, in projected_convert(x, otype)
#      38 def projected_convert(x, otype):
# ---> 39     return g.project(g.convert(x, otype), "defect")
#
# File ~/Documents/Physics/lattice/gpt/lib/gpt/core/convert.py:36, in convert(first, second)
#      33 if isinstance(first, gpt.expr):
#      34     first = gpt(first)
# ---> 36 return first.__class__.foundation.convert(first, second)
#
# File ~/Documents/Physics/lattice/gpt/lib/gpt/core/foundation/lattice/__init__.py:157, in convert(first, second)
#     155     if src.otype.__name__ == second.__name__:
#     156         return gpt.copy(src)
# --> 157     return convert(gpt.lattice(src.grid, second), src)
#     159 elif isinstance(first, gpt.lattice):
#     160     # second may be expression
#     161     second = gpt.eval(second)
#
# File ~/Documents/Physics/lattice/gpt/lib/gpt/core/foundation/lattice/__init__.py:167, in convert(first, second)
#     165 assert first.otype.__name__ in second.otype.ctab
#     166 tmp = gpt.lattice(first)
# --> 167 second.otype.ctab[first.otype.__name__](tmp, second)
#     168 second = tmp
#     169 assert first.otype.__name__ == second.otype.__name__
#
# File ~/Documents/Physics/lattice/gpt/lib/gpt/core/object_type/su_n.py:192, in ot_matrix_su_n_fundamental_algebra.__init__.<locals>._convert(dst, src)
#     191 def _convert(dst, src):
# --> 192     dst @= gpt.matrix.exp(src * 1j)
#
# File ~/Documents/Physics/lattice/gpt/lib/gpt/core/matrix/exp.py:33, in functor.__call__(self, i)
#      31 t = g.timer("exp")
#      32 t("matrix")
# ---> 33 r = i.__class__.foundation.matrix.exp.function(i)
#      34 t()
#      35 if self.verbose:
#
# File ~/Documents/Physics/lattice/gpt/lib/gpt/core/foundation/lattice/matrix/exp.py:178, in function(i, cache)
#     174             code.append((_o, _o, nfac, [(_xn, 0, 0)]))
#     176         cache[tag] = g.local_stencil.matrix(x, points, code)
# --> 178     cache[tag](o, xn, x)
#     179 else:
#     180     o += xn
#
# File ~/Documents/Physics/lattice/gpt/lib/gpt/core/auto_tune.py:44, in auto_tuned_method.<locals>.wrapper(self, *args)
#      42 def wrapper(self, *args):
#      43     if not self.at_active:
# ---> 44         return method(self, self.at_default_param, *args)
#      46     if self.at_tuned_params is not None:
#      47         return method(self, self.at_tuned_params["params"], *args)
#
# File ~/Documents/Physics/lattice/gpt/lib/gpt/core/local_stencil/matrix.py:52, in matrix.__call__(self, fast_osites, *fields)
#      50 @auto_tuned_method
#      51 def __call__(self, fast_osites, *fields):
# ---> 52     cgpt.stencil_matrix_execute(self.obj, list(fields), fast_osites)
#
# KeyboardInterrupt:

# %%
def MC_run(mdint__, tau):
    V = g.copy(U)
    Ei = MC_Ham(U)
    tau1 = tau * (np.random.randint(0,2)*2 - 1) 
    mdint__2(tau)
    Ef = MC_Ham(U)
    if np.exp(- (Ef - Ei)) < np.random.uniform(0,1):
        for mu in range(4):
            U[mu] @= V[mu]
        print("REJECT", "DELTA S = ", Ef - Ei )
    
        return 0

    else:
        return 1

# %%
# For GPT its easiest for me to just generate MDint_(shift direction)_(block sizes)_(even / odd) # smth is wrong
# working for lat size 4 block size 2 untested for larger lat size
MD_steps = 50
combos = [[0,1], [0,2], [0,3], [1,2], [1,3], [2,3]]
#combos = [[0,2], [2,3]]
#sizes = [2,4]
sizes = [2,4]

parity = [True, False]

#combos = [[0,2]]
#sizes = [2,]
#parity = [True]

# ll = direction, ff = sizes, ppa = parity
template = """
def gauge_force_coord_update_{ff}_{ll}_{ppa}(frozen_links, momenta_mask, block_size):
    # calculate gradients
    V = action_gauge.gradient(U, U)
    
    # shift to other domain ; should be done in 2 of 3 directions, and these can al be the same
    for i in combos[{ll}]:
        for mu in range(grid.nd):
            V[mu] = g.cshift(V[mu], i, block_size)

    for mu in range(grid.nd):
        V[mu] @= g(V[mu] * frozen_links[mu] * momenta_mask[mu]) # also need mask to block the other active domain!!!
    
    #print(V)
    
    x = log(lambda: V , "gauge")()
    
    return x

def gauge_force_mom_update_{ff}_{ll}_{ppa}(frozen_links, coordinate_mask, block_size):

     # calculate gradients
    V = action_gauge.gradient(U, U)
    
    # shift to other domain
    for i in combos[{ll}]:
        for mu in range(grid.nd):
            V[mu] = g.cshift(V[mu], i, -block_size)
        
    for mu in range(grid.nd):
        V[mu] @= g(V[mu] * frozen_links[mu] * coordinate_mask[mu])
    
    
    x = log(lambda: V , "gauge")()
    
    return x

block_size_{ff}_{ll}_{ppa} = sizes[{ff}]

even_coords_{ff}_{ll}_{ppa} = g.domain.even_odd_blocks(grid, [block_size_{ff}_{ll}_{ppa} for i in range(grid.nd)], g.even).gcoor
odd_coords_{ff}_{ll}_{ppa} = g.domain.even_odd_blocks(grid, [block_size_{ff}_{ll}_{ppa} for i in range(grid.nd)], g.odd).gcoor

# need to sort this out because the default is [0,1], so I'll need to swap zero only if the first digit changes

# need to do for second coord regardless
for i in range(len(even_coords_{ff}_{ll}_{ppa})):
    x = even_coords_{ff}_{ll}_{ppa}[i].copy()
    even_coords_{ff}_{ll}_{ppa}[i][1] = x[combos[{ll}][1]]
    even_coords_{ff}_{ll}_{ppa}[i][combos[{ll}][1]] = x[1]

    y = odd_coords_{ff}_{ll}_{ppa}[i].copy()
    odd_coords_{ff}_{ll}_{ppa}[i][1] = x[combos[{ll}][1]]
    odd_coords_{ff}_{ll}_{ppa}[i][combos[{ll}][1]] = x[1]

    if combos[{ll}][0] != 0:
        x = even_coords_{ff}_{ll}_{ppa}[i].copy()
        even_coords_{ff}_{ll}_{ppa}[i][0] = x[combos[{ll}][0]]
        even_coords_{ff}_{ll}_{ppa}[i][combos[{ll}][0]] = x[0]
    
        y = odd_coords_{ff}_{ll}_{ppa}[i].copy()
        odd_coords_{ff}_{ll}_{ppa}[i][0] = y[combos[{ll}][0]]
        odd_coords_{ff}_{ll}_{ppa}[i][combos[{ll}][0]] = y[0]


even_{ff}_{ll}_{ppa} = parity[{ppa}]

frozen_{ff}_{ll}_{ppa} = freeze_connecting_links(block_size_{ff}_{ll}_{ppa}, even_coords_{ff}_{ll}_{ppa}, odd_coords_{ff}_{ll}_{ppa}, even_{ff}_{ll}_{ppa})
coord_mask_{ff}_{ll}_{ppa} = coordinate_mask(block_size_{ff}_{ll}_{ppa}, even_coords_{ff}_{ll}_{ppa}, odd_coords_{ff}_{ll}_{ppa}, even_{ff}_{ll}_{ppa})
mom_mask_{ff}_{ll}_{ppa} = momentum_mask(block_size_{ff}_{ll}_{ppa}, even_coords_{ff}_{ll}_{ppa}, odd_coords_{ff}_{ll}_{ppa}, even_{ff}_{ll}_{ppa})


iq_{ff}_{ll}_{ppa} = sympl.update_q(   
    U, log(lambda: gauge_force_coord_update_{ff}_{ll}_{ppa}(frozen_{ff}_{ll}_{ppa}, mom_mask_{ff}_{ll}_{ppa}, block_size_{ff}_{ll}_{ppa}), "gauge_force_coord_update_{ff}_{ll}_{ppa}")
)

ip_{ff}_{ll}_{ppa} = sympl.update_p(
    U, log(lambda: gauge_force_mom_update_{ff}_{ll}_{ppa}(frozen_{ff}_{ll}_{ppa}, coord_mask_{ff}_{ll}_{ppa}, block_size_{ff}_{ll}_{ppa}), "gauge_force_mom_update_{ff}_{ll}_{ppa}")
)

# integrator
mdint_{ff}_{ll}_{ppa} = sympl.leap_frog(MD_steps, iq_{ff}_{ll}_{ppa}, ip_{ff}_{ll}_{ppa})
"""

# Build the code
code = []
for ff in range(len(sizes)):
    for ll in range(len(combos)):
        for ppa in range(len(parity)):
            code.append(template.format(ll = ll, ff = ff, ppa=ppa))

full_src = "\n".join(code)
print(full_src)
# Now load them into this module’s namespace
exec(full_src, globals())
# Out:
# def gauge_force_coord_update_0_0_0(frozen_links, momenta_mask, block_size):
#     # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain ; should be done in 2 of 3 directions, and these can al be the same
#     for i in combos[0]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * momenta_mask[mu]) # also need mask to block the other active domain!!!
#
#     #print(V)
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# def gauge_force_mom_update_0_0_0(frozen_links, coordinate_mask, block_size):
#
#      # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain
#     for i in combos[0]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, -block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * coordinate_mask[mu])
#
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# block_size_0_0_0 = sizes[0]
#
# even_coords_0_0_0 = g.domain.even_odd_blocks(grid, [block_size_0_0_0 for i in range(grid.nd)], g.even).gcoor
# odd_coords_0_0_0 = g.domain.even_odd_blocks(grid, [block_size_0_0_0 for i in range(grid.nd)], g.odd).gcoor
#
# # need to sort this out because the default is [0,1], so I'll need to swap zero only if the first digit changes
#
# # need to do for second coord regardless
# for i in range(len(even_coords_0_0_0)):
#     x = even_coords_0_0_0[i].copy()
#     even_coords_0_0_0[i][1] = x[combos[0][1]]
#     even_coords_0_0_0[i][combos[0][1]] = x[1]
#
#     y = odd_coords_0_0_0[i].copy()
#     odd_coords_0_0_0[i][1] = x[combos[0][1]]
#     odd_coords_0_0_0[i][combos[0][1]] = x[1]
#
#     if combos[0][0] != 0:
#         x = even_coords_0_0_0[i].copy()
#         even_coords_0_0_0[i][0] = x[combos[0][0]]
#         even_coords_0_0_0[i][combos[0][0]] = x[0]
#
#         y = odd_coords_0_0_0[i].copy()
#         odd_coords_0_0_0[i][0] = y[combos[0][0]]
#         odd_coords_0_0_0[i][combos[0][0]] = y[0]
#
#
# even_0_0_0 = parity[0]
#
# frozen_0_0_0 = freeze_connecting_links(block_size_0_0_0, even_coords_0_0_0, odd_coords_0_0_0, even_0_0_0)
# coord_mask_0_0_0 = coordinate_mask(block_size_0_0_0, even_coords_0_0_0, odd_coords_0_0_0, even_0_0_0)
# mom_mask_0_0_0 = momentum_mask(block_size_0_0_0, even_coords_0_0_0, odd_coords_0_0_0, even_0_0_0)
#
#
# iq_0_0_0 = sympl.update_q(
#     U, log(lambda: gauge_force_coord_update_0_0_0(frozen_0_0_0, mom_mask_0_0_0, block_size_0_0_0), "gauge_force_coord_update_0_0_0")
# )
#
# ip_0_0_0 = sympl.update_p(
#     U, log(lambda: gauge_force_mom_update_0_0_0(frozen_0_0_0, coord_mask_0_0_0, block_size_0_0_0), "gauge_force_mom_update_0_0_0")
# )
#
# # integrator
# mdint_0_0_0 = sympl.leap_frog(MD_steps, iq_0_0_0, ip_0_0_0)
#
#
# def gauge_force_coord_update_0_0_1(frozen_links, momenta_mask, block_size):
#     # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain ; should be done in 2 of 3 directions, and these can al be the same
#     for i in combos[0]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * momenta_mask[mu]) # also need mask to block the other active domain!!!
#
#     #print(V)
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# def gauge_force_mom_update_0_0_1(frozen_links, coordinate_mask, block_size):
#
#      # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain
#     for i in combos[0]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, -block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * coordinate_mask[mu])
#
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# block_size_0_0_1 = sizes[0]
#
# even_coords_0_0_1 = g.domain.even_odd_blocks(grid, [block_size_0_0_1 for i in range(grid.nd)], g.even).gcoor
# odd_coords_0_0_1 = g.domain.even_odd_blocks(grid, [block_size_0_0_1 for i in range(grid.nd)], g.odd).gcoor
#
# # need to sort this out because the default is [0,1], so I'll need to swap zero only if the first digit changes
#
# # need to do for second coord regardless
# for i in range(len(even_coords_0_0_1)):
#     x = even_coords_0_0_1[i].copy()
#     even_coords_0_0_1[i][1] = x[combos[0][1]]
#     even_coords_0_0_1[i][combos[0][1]] = x[1]
#
#     y = odd_coords_0_0_1[i].copy()
#     odd_coords_0_0_1[i][1] = x[combos[0][1]]
#     odd_coords_0_0_1[i][combos[0][1]] = x[1]
#
#     if combos[0][0] != 0:
#         x = even_coords_0_0_1[i].copy()
#         even_coords_0_0_1[i][0] = x[combos[0][0]]
#         even_coords_0_0_1[i][combos[0][0]] = x[0]
#
#         y = odd_coords_0_0_1[i].copy()
#         odd_coords_0_0_1[i][0] = y[combos[0][0]]
#         odd_coords_0_0_1[i][combos[0][0]] = y[0]
#
#
# even_0_0_1 = parity[1]
#
# frozen_0_0_1 = freeze_connecting_links(block_size_0_0_1, even_coords_0_0_1, odd_coords_0_0_1, even_0_0_1)
# coord_mask_0_0_1 = coordinate_mask(block_size_0_0_1, even_coords_0_0_1, odd_coords_0_0_1, even_0_0_1)
# mom_mask_0_0_1 = momentum_mask(block_size_0_0_1, even_coords_0_0_1, odd_coords_0_0_1, even_0_0_1)
#
#
# iq_0_0_1 = sympl.update_q(
#     U, log(lambda: gauge_force_coord_update_0_0_1(frozen_0_0_1, mom_mask_0_0_1, block_size_0_0_1), "gauge_force_coord_update_0_0_1")
# )
#
# ip_0_0_1 = sympl.update_p(
#     U, log(lambda: gauge_force_mom_update_0_0_1(frozen_0_0_1, coord_mask_0_0_1, block_size_0_0_1), "gauge_force_mom_update_0_0_1")
# )
#
# # integrator
# mdint_0_0_1 = sympl.leap_frog(MD_steps, iq_0_0_1, ip_0_0_1)
#
#
# def gauge_force_coord_update_0_1_0(frozen_links, momenta_mask, block_size):
#     # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain ; should be done in 2 of 3 directions, and these can al be the same
#     for i in combos[1]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * momenta_mask[mu]) # also need mask to block the other active domain!!!
#
#     #print(V)
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# def gauge_force_mom_update_0_1_0(frozen_links, coordinate_mask, block_size):
#
#      # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain
#     for i in combos[1]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, -block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * coordinate_mask[mu])
#
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# block_size_0_1_0 = sizes[0]
#
# even_coords_0_1_0 = g.domain.even_odd_blocks(grid, [block_size_0_1_0 for i in range(grid.nd)], g.even).gcoor
# odd_coords_0_1_0 = g.domain.even_odd_blocks(grid, [block_size_0_1_0 for i in range(grid.nd)], g.odd).gcoor
#
# # need to sort this out because the default is [0,1], so I'll need to swap zero only if the first digit changes
#
# # need to do for second coord regardless
# for i in range(len(even_coords_0_1_0)):
#     x = even_coords_0_1_0[i].copy()
#     even_coords_0_1_0[i][1] = x[combos[1][1]]
#     even_coords_0_1_0[i][combos[1][1]] = x[1]
#
#     y = odd_coords_0_1_0[i].copy()
#     odd_coords_0_1_0[i][1] = x[combos[1][1]]
#     odd_coords_0_1_0[i][combos[1][1]] = x[1]
#
#     if combos[1][0] != 0:
#         x = even_coords_0_1_0[i].copy()
#         even_coords_0_1_0[i][0] = x[combos[1][0]]
#         even_coords_0_1_0[i][combos[1][0]] = x[0]
#
#         y = odd_coords_0_1_0[i].copy()
#         odd_coords_0_1_0[i][0] = y[combos[1][0]]
#         odd_coords_0_1_0[i][combos[1][0]] = y[0]
#
#
# even_0_1_0 = parity[0]
#
# frozen_0_1_0 = freeze_connecting_links(block_size_0_1_0, even_coords_0_1_0, odd_coords_0_1_0, even_0_1_0)
# coord_mask_0_1_0 = coordinate_mask(block_size_0_1_0, even_coords_0_1_0, odd_coords_0_1_0, even_0_1_0)
# mom_mask_0_1_0 = momentum_mask(block_size_0_1_0, even_coords_0_1_0, odd_coords_0_1_0, even_0_1_0)
#
#
# iq_0_1_0 = sympl.update_q(
#     U, log(lambda: gauge_force_coord_update_0_1_0(frozen_0_1_0, mom_mask_0_1_0, block_size_0_1_0), "gauge_force_coord_update_0_1_0")
# )
#
# ip_0_1_0 = sympl.update_p(
#     U, log(lambda: gauge_force_mom_update_0_1_0(frozen_0_1_0, coord_mask_0_1_0, block_size_0_1_0), "gauge_force_mom_update_0_1_0")
# )
#
# # integrator
# mdint_0_1_0 = sympl.leap_frog(MD_steps, iq_0_1_0, ip_0_1_0)
#
#
# def gauge_force_coord_update_0_1_1(frozen_links, momenta_mask, block_size):
#     # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain ; should be done in 2 of 3 directions, and these can al be the same
#     for i in combos[1]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * momenta_mask[mu]) # also need mask to block the other active domain!!!
#
#     #print(V)
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# def gauge_force_mom_update_0_1_1(frozen_links, coordinate_mask, block_size):
#
#      # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain
#     for i in combos[1]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, -block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * coordinate_mask[mu])
#
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# block_size_0_1_1 = sizes[0]
#
# even_coords_0_1_1 = g.domain.even_odd_blocks(grid, [block_size_0_1_1 for i in range(grid.nd)], g.even).gcoor
# odd_coords_0_1_1 = g.domain.even_odd_blocks(grid, [block_size_0_1_1 for i in range(grid.nd)], g.odd).gcoor
#
# # need to sort this out because the default is [0,1], so I'll need to swap zero only if the first digit changes
#
# # need to do for second coord regardless
# for i in range(len(even_coords_0_1_1)):
#     x = even_coords_0_1_1[i].copy()
#     even_coords_0_1_1[i][1] = x[combos[1][1]]
#     even_coords_0_1_1[i][combos[1][1]] = x[1]
#
#     y = odd_coords_0_1_1[i].copy()
#     odd_coords_0_1_1[i][1] = x[combos[1][1]]
#     odd_coords_0_1_1[i][combos[1][1]] = x[1]
#
#     if combos[1][0] != 0:
#         x = even_coords_0_1_1[i].copy()
#         even_coords_0_1_1[i][0] = x[combos[1][0]]
#         even_coords_0_1_1[i][combos[1][0]] = x[0]
#
#         y = odd_coords_0_1_1[i].copy()
#         odd_coords_0_1_1[i][0] = y[combos[1][0]]
#         odd_coords_0_1_1[i][combos[1][0]] = y[0]
#
#
# even_0_1_1 = parity[1]
#
# frozen_0_1_1 = freeze_connecting_links(block_size_0_1_1, even_coords_0_1_1, odd_coords_0_1_1, even_0_1_1)
# coord_mask_0_1_1 = coordinate_mask(block_size_0_1_1, even_coords_0_1_1, odd_coords_0_1_1, even_0_1_1)
# mom_mask_0_1_1 = momentum_mask(block_size_0_1_1, even_coords_0_1_1, odd_coords_0_1_1, even_0_1_1)
#
#
# iq_0_1_1 = sympl.update_q(
#     U, log(lambda: gauge_force_coord_update_0_1_1(frozen_0_1_1, mom_mask_0_1_1, block_size_0_1_1), "gauge_force_coord_update_0_1_1")
# )
#
# ip_0_1_1 = sympl.update_p(
#     U, log(lambda: gauge_force_mom_update_0_1_1(frozen_0_1_1, coord_mask_0_1_1, block_size_0_1_1), "gauge_force_mom_update_0_1_1")
# )
#
# # integrator
# mdint_0_1_1 = sympl.leap_frog(MD_steps, iq_0_1_1, ip_0_1_1)
#
#
# def gauge_force_coord_update_0_2_0(frozen_links, momenta_mask, block_size):
#     # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain ; should be done in 2 of 3 directions, and these can al be the same
#     for i in combos[2]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * momenta_mask[mu]) # also need mask to block the other active domain!!!
#
#     #print(V)
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# def gauge_force_mom_update_0_2_0(frozen_links, coordinate_mask, block_size):
#
#      # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain
#     for i in combos[2]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, -block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * coordinate_mask[mu])
#
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# block_size_0_2_0 = sizes[0]
#
# even_coords_0_2_0 = g.domain.even_odd_blocks(grid, [block_size_0_2_0 for i in range(grid.nd)], g.even).gcoor
# odd_coords_0_2_0 = g.domain.even_odd_blocks(grid, [block_size_0_2_0 for i in range(grid.nd)], g.odd).gcoor
#
# # need to sort this out because the default is [0,1], so I'll need to swap zero only if the first digit changes
#
# # need to do for second coord regardless
# for i in range(len(even_coords_0_2_0)):
#     x = even_coords_0_2_0[i].copy()
#     even_coords_0_2_0[i][1] = x[combos[2][1]]
#     even_coords_0_2_0[i][combos[2][1]] = x[1]
#
#     y = odd_coords_0_2_0[i].copy()
#     odd_coords_0_2_0[i][1] = x[combos[2][1]]
#     odd_coords_0_2_0[i][combos[2][1]] = x[1]
#
#     if combos[2][0] != 0:
#         x = even_coords_0_2_0[i].copy()
#         even_coords_0_2_0[i][0] = x[combos[2][0]]
#         even_coords_0_2_0[i][combos[2][0]] = x[0]
#
#         y = odd_coords_0_2_0[i].copy()
#         odd_coords_0_2_0[i][0] = y[combos[2][0]]
#         odd_coords_0_2_0[i][combos[2][0]] = y[0]
#
#
# even_0_2_0 = parity[0]
#
# frozen_0_2_0 = freeze_connecting_links(block_size_0_2_0, even_coords_0_2_0, odd_coords_0_2_0, even_0_2_0)
# coord_mask_0_2_0 = coordinate_mask(block_size_0_2_0, even_coords_0_2_0, odd_coords_0_2_0, even_0_2_0)
# mom_mask_0_2_0 = momentum_mask(block_size_0_2_0, even_coords_0_2_0, odd_coords_0_2_0, even_0_2_0)
#
#
# iq_0_2_0 = sympl.update_q(
#     U, log(lambda: gauge_force_coord_update_0_2_0(frozen_0_2_0, mom_mask_0_2_0, block_size_0_2_0), "gauge_force_coord_update_0_2_0")
# )
#
# ip_0_2_0 = sympl.update_p(
#     U, log(lambda: gauge_force_mom_update_0_2_0(frozen_0_2_0, coord_mask_0_2_0, block_size_0_2_0), "gauge_force_mom_update_0_2_0")
# )
#
# # integrator
# mdint_0_2_0 = sympl.leap_frog(MD_steps, iq_0_2_0, ip_0_2_0)
#
#
# def gauge_force_coord_update_0_2_1(frozen_links, momenta_mask, block_size):
#     # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain ; should be done in 2 of 3 directions, and these can al be the same
#     for i in combos[2]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * momenta_mask[mu]) # also need mask to block the other active domain!!!
#
#     #print(V)
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# def gauge_force_mom_update_0_2_1(frozen_links, coordinate_mask, block_size):
#
#      # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain
#     for i in combos[2]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, -block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * coordinate_mask[mu])
#
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# block_size_0_2_1 = sizes[0]
#
# even_coords_0_2_1 = g.domain.even_odd_blocks(grid, [block_size_0_2_1 for i in range(grid.nd)], g.even).gcoor
# odd_coords_0_2_1 = g.domain.even_odd_blocks(grid, [block_size_0_2_1 for i in range(grid.nd)], g.odd).gcoor
#
# # need to sort this out because the default is [0,1], so I'll need to swap zero only if the first digit changes
#
# # need to do for second coord regardless
# for i in range(len(even_coords_0_2_1)):
#     x = even_coords_0_2_1[i].copy()
#     even_coords_0_2_1[i][1] = x[combos[2][1]]
#     even_coords_0_2_1[i][combos[2][1]] = x[1]
#
#     y = odd_coords_0_2_1[i].copy()
#     odd_coords_0_2_1[i][1] = x[combos[2][1]]
#     odd_coords_0_2_1[i][combos[2][1]] = x[1]
#
#     if combos[2][0] != 0:
#         x = even_coords_0_2_1[i].copy()
#         even_coords_0_2_1[i][0] = x[combos[2][0]]
#         even_coords_0_2_1[i][combos[2][0]] = x[0]
#
#         y = odd_coords_0_2_1[i].copy()
#         odd_coords_0_2_1[i][0] = y[combos[2][0]]
#         odd_coords_0_2_1[i][combos[2][0]] = y[0]
#
#
# even_0_2_1 = parity[1]
#
# frozen_0_2_1 = freeze_connecting_links(block_size_0_2_1, even_coords_0_2_1, odd_coords_0_2_1, even_0_2_1)
# coord_mask_0_2_1 = coordinate_mask(block_size_0_2_1, even_coords_0_2_1, odd_coords_0_2_1, even_0_2_1)
# mom_mask_0_2_1 = momentum_mask(block_size_0_2_1, even_coords_0_2_1, odd_coords_0_2_1, even_0_2_1)
#
#
# iq_0_2_1 = sympl.update_q(
#     U, log(lambda: gauge_force_coord_update_0_2_1(frozen_0_2_1, mom_mask_0_2_1, block_size_0_2_1), "gauge_force_coord_update_0_2_1")
# )
#
# ip_0_2_1 = sympl.update_p(
#     U, log(lambda: gauge_force_mom_update_0_2_1(frozen_0_2_1, coord_mask_0_2_1, block_size_0_2_1), "gauge_force_mom_update_0_2_1")
# )
#
# # integrator
# mdint_0_2_1 = sympl.leap_frog(MD_steps, iq_0_2_1, ip_0_2_1)
#
#
# def gauge_force_coord_update_0_3_0(frozen_links, momenta_mask, block_size):
#     # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain ; should be done in 2 of 3 directions, and these can al be the same
#     for i in combos[3]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * momenta_mask[mu]) # also need mask to block the other active domain!!!
#
#     #print(V)
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# def gauge_force_mom_update_0_3_0(frozen_links, coordinate_mask, block_size):
#
#      # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain
#     for i in combos[3]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, -block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * coordinate_mask[mu])
#
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# block_size_0_3_0 = sizes[0]
#
# even_coords_0_3_0 = g.domain.even_odd_blocks(grid, [block_size_0_3_0 for i in range(grid.nd)], g.even).gcoor
# odd_coords_0_3_0 = g.domain.even_odd_blocks(grid, [block_size_0_3_0 for i in range(grid.nd)], g.odd).gcoor
#
# # need to sort this out because the default is [0,1], so I'll need to swap zero only if the first digit changes
#
# # need to do for second coord regardless
# for i in range(len(even_coords_0_3_0)):
#     x = even_coords_0_3_0[i].copy()
#     even_coords_0_3_0[i][1] = x[combos[3][1]]
#     even_coords_0_3_0[i][combos[3][1]] = x[1]
#
#     y = odd_coords_0_3_0[i].copy()
#     odd_coords_0_3_0[i][1] = x[combos[3][1]]
#     odd_coords_0_3_0[i][combos[3][1]] = x[1]
#
#     if combos[3][0] != 0:
#         x = even_coords_0_3_0[i].copy()
#         even_coords_0_3_0[i][0] = x[combos[3][0]]
#         even_coords_0_3_0[i][combos[3][0]] = x[0]
#
#         y = odd_coords_0_3_0[i].copy()
#         odd_coords_0_3_0[i][0] = y[combos[3][0]]
#         odd_coords_0_3_0[i][combos[3][0]] = y[0]
#
#
# even_0_3_0 = parity[0]
#
# frozen_0_3_0 = freeze_connecting_links(block_size_0_3_0, even_coords_0_3_0, odd_coords_0_3_0, even_0_3_0)
# coord_mask_0_3_0 = coordinate_mask(block_size_0_3_0, even_coords_0_3_0, odd_coords_0_3_0, even_0_3_0)
# mom_mask_0_3_0 = momentum_mask(block_size_0_3_0, even_coords_0_3_0, odd_coords_0_3_0, even_0_3_0)
#
#
# iq_0_3_0 = sympl.update_q(
#     U, log(lambda: gauge_force_coord_update_0_3_0(frozen_0_3_0, mom_mask_0_3_0, block_size_0_3_0), "gauge_force_coord_update_0_3_0")
# )
#
# ip_0_3_0 = sympl.update_p(
#     U, log(lambda: gauge_force_mom_update_0_3_0(frozen_0_3_0, coord_mask_0_3_0, block_size_0_3_0), "gauge_force_mom_update_0_3_0")
# )
#
# # integrator
# mdint_0_3_0 = sympl.leap_frog(MD_steps, iq_0_3_0, ip_0_3_0)
#
#
# def gauge_force_coord_update_0_3_1(frozen_links, momenta_mask, block_size):
#     # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain ; should be done in 2 of 3 directions, and these can al be the same
#     for i in combos[3]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * momenta_mask[mu]) # also need mask to block the other active domain!!!
#
#     #print(V)
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# def gauge_force_mom_update_0_3_1(frozen_links, coordinate_mask, block_size):
#
#      # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain
#     for i in combos[3]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, -block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * coordinate_mask[mu])
#
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# block_size_0_3_1 = sizes[0]
#
# even_coords_0_3_1 = g.domain.even_odd_blocks(grid, [block_size_0_3_1 for i in range(grid.nd)], g.even).gcoor
# odd_coords_0_3_1 = g.domain.even_odd_blocks(grid, [block_size_0_3_1 for i in range(grid.nd)], g.odd).gcoor
#
# # need to sort this out because the default is [0,1], so I'll need to swap zero only if the first digit changes
#
# # need to do for second coord regardless
# for i in range(len(even_coords_0_3_1)):
#     x = even_coords_0_3_1[i].copy()
#     even_coords_0_3_1[i][1] = x[combos[3][1]]
#     even_coords_0_3_1[i][combos[3][1]] = x[1]
#
#     y = odd_coords_0_3_1[i].copy()
#     odd_coords_0_3_1[i][1] = x[combos[3][1]]
#     odd_coords_0_3_1[i][combos[3][1]] = x[1]
#
#     if combos[3][0] != 0:
#         x = even_coords_0_3_1[i].copy()
#         even_coords_0_3_1[i][0] = x[combos[3][0]]
#         even_coords_0_3_1[i][combos[3][0]] = x[0]
#
#         y = odd_coords_0_3_1[i].copy()
#         odd_coords_0_3_1[i][0] = y[combos[3][0]]
#         odd_coords_0_3_1[i][combos[3][0]] = y[0]
#
#
# even_0_3_1 = parity[1]
#
# frozen_0_3_1 = freeze_connecting_links(block_size_0_3_1, even_coords_0_3_1, odd_coords_0_3_1, even_0_3_1)
# coord_mask_0_3_1 = coordinate_mask(block_size_0_3_1, even_coords_0_3_1, odd_coords_0_3_1, even_0_3_1)
# mom_mask_0_3_1 = momentum_mask(block_size_0_3_1, even_coords_0_3_1, odd_coords_0_3_1, even_0_3_1)
#
#
# iq_0_3_1 = sympl.update_q(
#     U, log(lambda: gauge_force_coord_update_0_3_1(frozen_0_3_1, mom_mask_0_3_1, block_size_0_3_1), "gauge_force_coord_update_0_3_1")
# )
#
# ip_0_3_1 = sympl.update_p(
#     U, log(lambda: gauge_force_mom_update_0_3_1(frozen_0_3_1, coord_mask_0_3_1, block_size_0_3_1), "gauge_force_mom_update_0_3_1")
# )
#
# # integrator
# mdint_0_3_1 = sympl.leap_frog(MD_steps, iq_0_3_1, ip_0_3_1)
#
#
# def gauge_force_coord_update_0_4_0(frozen_links, momenta_mask, block_size):
#     # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain ; should be done in 2 of 3 directions, and these can al be the same
#     for i in combos[4]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * momenta_mask[mu]) # also need mask to block the other active domain!!!
#
#     #print(V)
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# def gauge_force_mom_update_0_4_0(frozen_links, coordinate_mask, block_size):
#
#      # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain
#     for i in combos[4]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, -block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * coordinate_mask[mu])
#
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# block_size_0_4_0 = sizes[0]
#
# even_coords_0_4_0 = g.domain.even_odd_blocks(grid, [block_size_0_4_0 for i in range(grid.nd)], g.even).gcoor
# odd_coords_0_4_0 = g.domain.even_odd_blocks(grid, [block_size_0_4_0 for i in range(grid.nd)], g.odd).gcoor
#
# # need to sort this out because the default is [0,1], so I'll need to swap zero only if the first digit changes
#
# # need to do for second coord regardless
# for i in range(len(even_coords_0_4_0)):
#     x = even_coords_0_4_0[i].copy()
#     even_coords_0_4_0[i][1] = x[combos[4][1]]
#     even_coords_0_4_0[i][combos[4][1]] = x[1]
#
#     y = odd_coords_0_4_0[i].copy()
#     odd_coords_0_4_0[i][1] = x[combos[4][1]]
#     odd_coords_0_4_0[i][combos[4][1]] = x[1]
#
#     if combos[4][0] != 0:
#         x = even_coords_0_4_0[i].copy()
#         even_coords_0_4_0[i][0] = x[combos[4][0]]
#         even_coords_0_4_0[i][combos[4][0]] = x[0]
#
#         y = odd_coords_0_4_0[i].copy()
#         odd_coords_0_4_0[i][0] = y[combos[4][0]]
#         odd_coords_0_4_0[i][combos[4][0]] = y[0]
#
#
# even_0_4_0 = parity[0]
#
# frozen_0_4_0 = freeze_connecting_links(block_size_0_4_0, even_coords_0_4_0, odd_coords_0_4_0, even_0_4_0)
# coord_mask_0_4_0 = coordinate_mask(block_size_0_4_0, even_coords_0_4_0, odd_coords_0_4_0, even_0_4_0)
# mom_mask_0_4_0 = momentum_mask(block_size_0_4_0, even_coords_0_4_0, odd_coords_0_4_0, even_0_4_0)
#
#
# iq_0_4_0 = sympl.update_q(
#     U, log(lambda: gauge_force_coord_update_0_4_0(frozen_0_4_0, mom_mask_0_4_0, block_size_0_4_0), "gauge_force_coord_update_0_4_0")
# )
#
# ip_0_4_0 = sympl.update_p(
#     U, log(lambda: gauge_force_mom_update_0_4_0(frozen_0_4_0, coord_mask_0_4_0, block_size_0_4_0), "gauge_force_mom_update_0_4_0")
# )
#
# # integrator
# mdint_0_4_0 = sympl.leap_frog(MD_steps, iq_0_4_0, ip_0_4_0)
#
#
# def gauge_force_coord_update_0_4_1(frozen_links, momenta_mask, block_size):
#     # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain ; should be done in 2 of 3 directions, and these can al be the same
#     for i in combos[4]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * momenta_mask[mu]) # also need mask to block the other active domain!!!
#
#     #print(V)
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# def gauge_force_mom_update_0_4_1(frozen_links, coordinate_mask, block_size):
#
#      # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain
#     for i in combos[4]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, -block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * coordinate_mask[mu])
#
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# block_size_0_4_1 = sizes[0]
#
# even_coords_0_4_1 = g.domain.even_odd_blocks(grid, [block_size_0_4_1 for i in range(grid.nd)], g.even).gcoor
# odd_coords_0_4_1 = g.domain.even_odd_blocks(grid, [block_size_0_4_1 for i in range(grid.nd)], g.odd).gcoor
#
# # need to sort this out because the default is [0,1], so I'll need to swap zero only if the first digit changes
#
# # need to do for second coord regardless
# for i in range(len(even_coords_0_4_1)):
#     x = even_coords_0_4_1[i].copy()
#     even_coords_0_4_1[i][1] = x[combos[4][1]]
#     even_coords_0_4_1[i][combos[4][1]] = x[1]
#
#     y = odd_coords_0_4_1[i].copy()
#     odd_coords_0_4_1[i][1] = x[combos[4][1]]
#     odd_coords_0_4_1[i][combos[4][1]] = x[1]
#
#     if combos[4][0] != 0:
#         x = even_coords_0_4_1[i].copy()
#         even_coords_0_4_1[i][0] = x[combos[4][0]]
#         even_coords_0_4_1[i][combos[4][0]] = x[0]
#
#         y = odd_coords_0_4_1[i].copy()
#         odd_coords_0_4_1[i][0] = y[combos[4][0]]
#         odd_coords_0_4_1[i][combos[4][0]] = y[0]
#
#
# even_0_4_1 = parity[1]
#
# frozen_0_4_1 = freeze_connecting_links(block_size_0_4_1, even_coords_0_4_1, odd_coords_0_4_1, even_0_4_1)
# coord_mask_0_4_1 = coordinate_mask(block_size_0_4_1, even_coords_0_4_1, odd_coords_0_4_1, even_0_4_1)
# mom_mask_0_4_1 = momentum_mask(block_size_0_4_1, even_coords_0_4_1, odd_coords_0_4_1, even_0_4_1)
#
#
# iq_0_4_1 = sympl.update_q(
#     U, log(lambda: gauge_force_coord_update_0_4_1(frozen_0_4_1, mom_mask_0_4_1, block_size_0_4_1), "gauge_force_coord_update_0_4_1")
# )
#
# ip_0_4_1 = sympl.update_p(
#     U, log(lambda: gauge_force_mom_update_0_4_1(frozen_0_4_1, coord_mask_0_4_1, block_size_0_4_1), "gauge_force_mom_update_0_4_1")
# )
#
# # integrator
# mdint_0_4_1 = sympl.leap_frog(MD_steps, iq_0_4_1, ip_0_4_1)
#
#
# def gauge_force_coord_update_0_5_0(frozen_links, momenta_mask, block_size):
#     # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain ; should be done in 2 of 3 directions, and these can al be the same
#     for i in combos[5]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * momenta_mask[mu]) # also need mask to block the other active domain!!!
#
#     #print(V)
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# def gauge_force_mom_update_0_5_0(frozen_links, coordinate_mask, block_size):
#
#      # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain
#     for i in combos[5]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, -block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * coordinate_mask[mu])
#
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# block_size_0_5_0 = sizes[0]
#
# even_coords_0_5_0 = g.domain.even_odd_blocks(grid, [block_size_0_5_0 for i in range(grid.nd)], g.even).gcoor
# odd_coords_0_5_0 = g.domain.even_odd_blocks(grid, [block_size_0_5_0 for i in range(grid.nd)], g.odd).gcoor
#
# # need to sort this out because the default is [0,1], so I'll need to swap zero only if the first digit changes
#
# # need to do for second coord regardless
# for i in range(len(even_coords_0_5_0)):
#     x = even_coords_0_5_0[i].copy()
#     even_coords_0_5_0[i][1] = x[combos[5][1]]
#     even_coords_0_5_0[i][combos[5][1]] = x[1]
#
#     y = odd_coords_0_5_0[i].copy()
#     odd_coords_0_5_0[i][1] = x[combos[5][1]]
#     odd_coords_0_5_0[i][combos[5][1]] = x[1]
#
#     if combos[5][0] != 0:
#         x = even_coords_0_5_0[i].copy()
#         even_coords_0_5_0[i][0] = x[combos[5][0]]
#         even_coords_0_5_0[i][combos[5][0]] = x[0]
#
#         y = odd_coords_0_5_0[i].copy()
#         odd_coords_0_5_0[i][0] = y[combos[5][0]]
#         odd_coords_0_5_0[i][combos[5][0]] = y[0]
#
#
# even_0_5_0 = parity[0]
#
# frozen_0_5_0 = freeze_connecting_links(block_size_0_5_0, even_coords_0_5_0, odd_coords_0_5_0, even_0_5_0)
# coord_mask_0_5_0 = coordinate_mask(block_size_0_5_0, even_coords_0_5_0, odd_coords_0_5_0, even_0_5_0)
# mom_mask_0_5_0 = momentum_mask(block_size_0_5_0, even_coords_0_5_0, odd_coords_0_5_0, even_0_5_0)
#
#
# iq_0_5_0 = sympl.update_q(
#     U, log(lambda: gauge_force_coord_update_0_5_0(frozen_0_5_0, mom_mask_0_5_0, block_size_0_5_0), "gauge_force_coord_update_0_5_0")
# )
#
# ip_0_5_0 = sympl.update_p(
#     U, log(lambda: gauge_force_mom_update_0_5_0(frozen_0_5_0, coord_mask_0_5_0, block_size_0_5_0), "gauge_force_mom_update_0_5_0")
# )
#
# # integrator
# mdint_0_5_0 = sympl.leap_frog(MD_steps, iq_0_5_0, ip_0_5_0)
#
#
# def gauge_force_coord_update_0_5_1(frozen_links, momenta_mask, block_size):
#     # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain ; should be done in 2 of 3 directions, and these can al be the same
#     for i in combos[5]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * momenta_mask[mu]) # also need mask to block the other active domain!!!
#
#     #print(V)
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# def gauge_force_mom_update_0_5_1(frozen_links, coordinate_mask, block_size):
#
#      # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain
#     for i in combos[5]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, -block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * coordinate_mask[mu])
#
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# block_size_0_5_1 = sizes[0]
#
# even_coords_0_5_1 = g.domain.even_odd_blocks(grid, [block_size_0_5_1 for i in range(grid.nd)], g.even).gcoor
# odd_coords_0_5_1 = g.domain.even_odd_blocks(grid, [block_size_0_5_1 for i in range(grid.nd)], g.odd).gcoor
#
# # need to sort this out because the default is [0,1], so I'll need to swap zero only if the first digit changes
#
# # need to do for second coord regardless
# for i in range(len(even_coords_0_5_1)):
#     x = even_coords_0_5_1[i].copy()
#     even_coords_0_5_1[i][1] = x[combos[5][1]]
#     even_coords_0_5_1[i][combos[5][1]] = x[1]
#
#     y = odd_coords_0_5_1[i].copy()
#     odd_coords_0_5_1[i][1] = x[combos[5][1]]
#     odd_coords_0_5_1[i][combos[5][1]] = x[1]
#
#     if combos[5][0] != 0:
#         x = even_coords_0_5_1[i].copy()
#         even_coords_0_5_1[i][0] = x[combos[5][0]]
#         even_coords_0_5_1[i][combos[5][0]] = x[0]
#
#         y = odd_coords_0_5_1[i].copy()
#         odd_coords_0_5_1[i][0] = y[combos[5][0]]
#         odd_coords_0_5_1[i][combos[5][0]] = y[0]
#
#
# even_0_5_1 = parity[1]
#
# frozen_0_5_1 = freeze_connecting_links(block_size_0_5_1, even_coords_0_5_1, odd_coords_0_5_1, even_0_5_1)
# coord_mask_0_5_1 = coordinate_mask(block_size_0_5_1, even_coords_0_5_1, odd_coords_0_5_1, even_0_5_1)
# mom_mask_0_5_1 = momentum_mask(block_size_0_5_1, even_coords_0_5_1, odd_coords_0_5_1, even_0_5_1)
#
#
# iq_0_5_1 = sympl.update_q(
#     U, log(lambda: gauge_force_coord_update_0_5_1(frozen_0_5_1, mom_mask_0_5_1, block_size_0_5_1), "gauge_force_coord_update_0_5_1")
# )
#
# ip_0_5_1 = sympl.update_p(
#     U, log(lambda: gauge_force_mom_update_0_5_1(frozen_0_5_1, coord_mask_0_5_1, block_size_0_5_1), "gauge_force_mom_update_0_5_1")
# )
#
# # integrator
# mdint_0_5_1 = sympl.leap_frog(MD_steps, iq_0_5_1, ip_0_5_1)
#
#
# def gauge_force_coord_update_1_0_0(frozen_links, momenta_mask, block_size):
#     # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain ; should be done in 2 of 3 directions, and these can al be the same
#     for i in combos[0]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * momenta_mask[mu]) # also need mask to block the other active domain!!!
#
#     #print(V)
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# def gauge_force_mom_update_1_0_0(frozen_links, coordinate_mask, block_size):
#
#      # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain
#     for i in combos[0]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, -block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * coordinate_mask[mu])
#
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# block_size_1_0_0 = sizes[1]
#
# even_coords_1_0_0 = g.domain.even_odd_blocks(grid, [block_size_1_0_0 for i in range(grid.nd)], g.even).gcoor
# odd_coords_1_0_0 = g.domain.even_odd_blocks(grid, [block_size_1_0_0 for i in range(grid.nd)], g.odd).gcoor
#
# # need to sort this out because the default is [0,1], so I'll need to swap zero only if the first digit changes
#
# # need to do for second coord regardless
# for i in range(len(even_coords_1_0_0)):
#     x = even_coords_1_0_0[i].copy()
#     even_coords_1_0_0[i][1] = x[combos[0][1]]
#     even_coords_1_0_0[i][combos[0][1]] = x[1]
#
#     y = odd_coords_1_0_0[i].copy()
#     odd_coords_1_0_0[i][1] = x[combos[0][1]]
#     odd_coords_1_0_0[i][combos[0][1]] = x[1]
#
#     if combos[0][0] != 0:
#         x = even_coords_1_0_0[i].copy()
#         even_coords_1_0_0[i][0] = x[combos[0][0]]
#         even_coords_1_0_0[i][combos[0][0]] = x[0]
#
#         y = odd_coords_1_0_0[i].copy()
#         odd_coords_1_0_0[i][0] = y[combos[0][0]]
#         odd_coords_1_0_0[i][combos[0][0]] = y[0]
#
#
# even_1_0_0 = parity[0]
#
# frozen_1_0_0 = freeze_connecting_links(block_size_1_0_0, even_coords_1_0_0, odd_coords_1_0_0, even_1_0_0)
# coord_mask_1_0_0 = coordinate_mask(block_size_1_0_0, even_coords_1_0_0, odd_coords_1_0_0, even_1_0_0)
# mom_mask_1_0_0 = momentum_mask(block_size_1_0_0, even_coords_1_0_0, odd_coords_1_0_0, even_1_0_0)
#
#
# iq_1_0_0 = sympl.update_q(
#     U, log(lambda: gauge_force_coord_update_1_0_0(frozen_1_0_0, mom_mask_1_0_0, block_size_1_0_0), "gauge_force_coord_update_1_0_0")
# )
#
# ip_1_0_0 = sympl.update_p(
#     U, log(lambda: gauge_force_mom_update_1_0_0(frozen_1_0_0, coord_mask_1_0_0, block_size_1_0_0), "gauge_force_mom_update_1_0_0")
# )
#
# # integrator
# mdint_1_0_0 = sympl.leap_frog(MD_steps, iq_1_0_0, ip_1_0_0)
#
#
# def gauge_force_coord_update_1_0_1(frozen_links, momenta_mask, block_size):
#     # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain ; should be done in 2 of 3 directions, and these can al be the same
#     for i in combos[0]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * momenta_mask[mu]) # also need mask to block the other active domain!!!
#
#     #print(V)
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# def gauge_force_mom_update_1_0_1(frozen_links, coordinate_mask, block_size):
#
#      # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain
#     for i in combos[0]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, -block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * coordinate_mask[mu])
#
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# block_size_1_0_1 = sizes[1]
#
# even_coords_1_0_1 = g.domain.even_odd_blocks(grid, [block_size_1_0_1 for i in range(grid.nd)], g.even).gcoor
# odd_coords_1_0_1 = g.domain.even_odd_blocks(grid, [block_size_1_0_1 for i in range(grid.nd)], g.odd).gcoor
#
# # need to sort this out because the default is [0,1], so I'll need to swap zero only if the first digit changes
#
# # need to do for second coord regardless
# for i in range(len(even_coords_1_0_1)):
#     x = even_coords_1_0_1[i].copy()
#     even_coords_1_0_1[i][1] = x[combos[0][1]]
#     even_coords_1_0_1[i][combos[0][1]] = x[1]
#
#     y = odd_coords_1_0_1[i].copy()
#     odd_coords_1_0_1[i][1] = x[combos[0][1]]
#     odd_coords_1_0_1[i][combos[0][1]] = x[1]
#
#     if combos[0][0] != 0:
#         x = even_coords_1_0_1[i].copy()
#         even_coords_1_0_1[i][0] = x[combos[0][0]]
#         even_coords_1_0_1[i][combos[0][0]] = x[0]
#
#         y = odd_coords_1_0_1[i].copy()
#         odd_coords_1_0_1[i][0] = y[combos[0][0]]
#         odd_coords_1_0_1[i][combos[0][0]] = y[0]
#
#
# even_1_0_1 = parity[1]
#
# frozen_1_0_1 = freeze_connecting_links(block_size_1_0_1, even_coords_1_0_1, odd_coords_1_0_1, even_1_0_1)
# coord_mask_1_0_1 = coordinate_mask(block_size_1_0_1, even_coords_1_0_1, odd_coords_1_0_1, even_1_0_1)
# mom_mask_1_0_1 = momentum_mask(block_size_1_0_1, even_coords_1_0_1, odd_coords_1_0_1, even_1_0_1)
#
#
# iq_1_0_1 = sympl.update_q(
#     U, log(lambda: gauge_force_coord_update_1_0_1(frozen_1_0_1, mom_mask_1_0_1, block_size_1_0_1), "gauge_force_coord_update_1_0_1")
# )
#
# ip_1_0_1 = sympl.update_p(
#     U, log(lambda: gauge_force_mom_update_1_0_1(frozen_1_0_1, coord_mask_1_0_1, block_size_1_0_1), "gauge_force_mom_update_1_0_1")
# )
#
# # integrator
# mdint_1_0_1 = sympl.leap_frog(MD_steps, iq_1_0_1, ip_1_0_1)
#
#
# def gauge_force_coord_update_1_1_0(frozen_links, momenta_mask, block_size):
#     # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain ; should be done in 2 of 3 directions, and these can al be the same
#     for i in combos[1]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * momenta_mask[mu]) # also need mask to block the other active domain!!!
#
#     #print(V)
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# def gauge_force_mom_update_1_1_0(frozen_links, coordinate_mask, block_size):
#
#      # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain
#     for i in combos[1]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, -block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * coordinate_mask[mu])
#
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# block_size_1_1_0 = sizes[1]
#
# even_coords_1_1_0 = g.domain.even_odd_blocks(grid, [block_size_1_1_0 for i in range(grid.nd)], g.even).gcoor
# odd_coords_1_1_0 = g.domain.even_odd_blocks(grid, [block_size_1_1_0 for i in range(grid.nd)], g.odd).gcoor
#
# # need to sort this out because the default is [0,1], so I'll need to swap zero only if the first digit changes
#
# # need to do for second coord regardless
# for i in range(len(even_coords_1_1_0)):
#     x = even_coords_1_1_0[i].copy()
#     even_coords_1_1_0[i][1] = x[combos[1][1]]
#     even_coords_1_1_0[i][combos[1][1]] = x[1]
#
#     y = odd_coords_1_1_0[i].copy()
#     odd_coords_1_1_0[i][1] = x[combos[1][1]]
#     odd_coords_1_1_0[i][combos[1][1]] = x[1]
#
#     if combos[1][0] != 0:
#         x = even_coords_1_1_0[i].copy()
#         even_coords_1_1_0[i][0] = x[combos[1][0]]
#         even_coords_1_1_0[i][combos[1][0]] = x[0]
#
#         y = odd_coords_1_1_0[i].copy()
#         odd_coords_1_1_0[i][0] = y[combos[1][0]]
#         odd_coords_1_1_0[i][combos[1][0]] = y[0]
#
#
# even_1_1_0 = parity[0]
#
# frozen_1_1_0 = freeze_connecting_links(block_size_1_1_0, even_coords_1_1_0, odd_coords_1_1_0, even_1_1_0)
# coord_mask_1_1_0 = coordinate_mask(block_size_1_1_0, even_coords_1_1_0, odd_coords_1_1_0, even_1_1_0)
# mom_mask_1_1_0 = momentum_mask(block_size_1_1_0, even_coords_1_1_0, odd_coords_1_1_0, even_1_1_0)
#
#
# iq_1_1_0 = sympl.update_q(
#     U, log(lambda: gauge_force_coord_update_1_1_0(frozen_1_1_0, mom_mask_1_1_0, block_size_1_1_0), "gauge_force_coord_update_1_1_0")
# )
#
# ip_1_1_0 = sympl.update_p(
#     U, log(lambda: gauge_force_mom_update_1_1_0(frozen_1_1_0, coord_mask_1_1_0, block_size_1_1_0), "gauge_force_mom_update_1_1_0")
# )
#
# # integrator
# mdint_1_1_0 = sympl.leap_frog(MD_steps, iq_1_1_0, ip_1_1_0)
#
#
# def gauge_force_coord_update_1_1_1(frozen_links, momenta_mask, block_size):
#     # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain ; should be done in 2 of 3 directions, and these can al be the same
#     for i in combos[1]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * momenta_mask[mu]) # also need mask to block the other active domain!!!
#
#     #print(V)
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# def gauge_force_mom_update_1_1_1(frozen_links, coordinate_mask, block_size):
#
#      # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain
#     for i in combos[1]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, -block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * coordinate_mask[mu])
#
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# block_size_1_1_1 = sizes[1]
#
# even_coords_1_1_1 = g.domain.even_odd_blocks(grid, [block_size_1_1_1 for i in range(grid.nd)], g.even).gcoor
# odd_coords_1_1_1 = g.domain.even_odd_blocks(grid, [block_size_1_1_1 for i in range(grid.nd)], g.odd).gcoor
#
# # need to sort this out because the default is [0,1], so I'll need to swap zero only if the first digit changes
#
# # need to do for second coord regardless
# for i in range(len(even_coords_1_1_1)):
#     x = even_coords_1_1_1[i].copy()
#     even_coords_1_1_1[i][1] = x[combos[1][1]]
#     even_coords_1_1_1[i][combos[1][1]] = x[1]
#
#     y = odd_coords_1_1_1[i].copy()
#     odd_coords_1_1_1[i][1] = x[combos[1][1]]
#     odd_coords_1_1_1[i][combos[1][1]] = x[1]
#
#     if combos[1][0] != 0:
#         x = even_coords_1_1_1[i].copy()
#         even_coords_1_1_1[i][0] = x[combos[1][0]]
#         even_coords_1_1_1[i][combos[1][0]] = x[0]
#
#         y = odd_coords_1_1_1[i].copy()
#         odd_coords_1_1_1[i][0] = y[combos[1][0]]
#         odd_coords_1_1_1[i][combos[1][0]] = y[0]
#
#
# even_1_1_1 = parity[1]
#
# frozen_1_1_1 = freeze_connecting_links(block_size_1_1_1, even_coords_1_1_1, odd_coords_1_1_1, even_1_1_1)
# coord_mask_1_1_1 = coordinate_mask(block_size_1_1_1, even_coords_1_1_1, odd_coords_1_1_1, even_1_1_1)
# mom_mask_1_1_1 = momentum_mask(block_size_1_1_1, even_coords_1_1_1, odd_coords_1_1_1, even_1_1_1)
#
#
# iq_1_1_1 = sympl.update_q(
#     U, log(lambda: gauge_force_coord_update_1_1_1(frozen_1_1_1, mom_mask_1_1_1, block_size_1_1_1), "gauge_force_coord_update_1_1_1")
# )
#
# ip_1_1_1 = sympl.update_p(
#     U, log(lambda: gauge_force_mom_update_1_1_1(frozen_1_1_1, coord_mask_1_1_1, block_size_1_1_1), "gauge_force_mom_update_1_1_1")
# )
#
# # integrator
# mdint_1_1_1 = sympl.leap_frog(MD_steps, iq_1_1_1, ip_1_1_1)
#
#
# def gauge_force_coord_update_1_2_0(frozen_links, momenta_mask, block_size):
#     # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain ; should be done in 2 of 3 directions, and these can al be the same
#     for i in combos[2]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * momenta_mask[mu]) # also need mask to block the other active domain!!!
#
#     #print(V)
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# def gauge_force_mom_update_1_2_0(frozen_links, coordinate_mask, block_size):
#
#      # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain
#     for i in combos[2]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, -block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * coordinate_mask[mu])
#
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# block_size_1_2_0 = sizes[1]
#
# even_coords_1_2_0 = g.domain.even_odd_blocks(grid, [block_size_1_2_0 for i in range(grid.nd)], g.even).gcoor
# odd_coords_1_2_0 = g.domain.even_odd_blocks(grid, [block_size_1_2_0 for i in range(grid.nd)], g.odd).gcoor
#
# # need to sort this out because the default is [0,1], so I'll need to swap zero only if the first digit changes
#
# # need to do for second coord regardless
# for i in range(len(even_coords_1_2_0)):
#     x = even_coords_1_2_0[i].copy()
#     even_coords_1_2_0[i][1] = x[combos[2][1]]
#     even_coords_1_2_0[i][combos[2][1]] = x[1]
#
#     y = odd_coords_1_2_0[i].copy()
#     odd_coords_1_2_0[i][1] = x[combos[2][1]]
#     odd_coords_1_2_0[i][combos[2][1]] = x[1]
#
#     if combos[2][0] != 0:
#         x = even_coords_1_2_0[i].copy()
#         even_coords_1_2_0[i][0] = x[combos[2][0]]
#         even_coords_1_2_0[i][combos[2][0]] = x[0]
#
#         y = odd_coords_1_2_0[i].copy()
#         odd_coords_1_2_0[i][0] = y[combos[2][0]]
#         odd_coords_1_2_0[i][combos[2][0]] = y[0]
#
#
# even_1_2_0 = parity[0]
#
# frozen_1_2_0 = freeze_connecting_links(block_size_1_2_0, even_coords_1_2_0, odd_coords_1_2_0, even_1_2_0)
# coord_mask_1_2_0 = coordinate_mask(block_size_1_2_0, even_coords_1_2_0, odd_coords_1_2_0, even_1_2_0)
# mom_mask_1_2_0 = momentum_mask(block_size_1_2_0, even_coords_1_2_0, odd_coords_1_2_0, even_1_2_0)
#
#
# iq_1_2_0 = sympl.update_q(
#     U, log(lambda: gauge_force_coord_update_1_2_0(frozen_1_2_0, mom_mask_1_2_0, block_size_1_2_0), "gauge_force_coord_update_1_2_0")
# )
#
# ip_1_2_0 = sympl.update_p(
#     U, log(lambda: gauge_force_mom_update_1_2_0(frozen_1_2_0, coord_mask_1_2_0, block_size_1_2_0), "gauge_force_mom_update_1_2_0")
# )
#
# # integrator
# mdint_1_2_0 = sympl.leap_frog(MD_steps, iq_1_2_0, ip_1_2_0)
#
#
# def gauge_force_coord_update_1_2_1(frozen_links, momenta_mask, block_size):
#     # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain ; should be done in 2 of 3 directions, and these can al be the same
#     for i in combos[2]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * momenta_mask[mu]) # also need mask to block the other active domain!!!
#
#     #print(V)
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# def gauge_force_mom_update_1_2_1(frozen_links, coordinate_mask, block_size):
#
#      # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain
#     for i in combos[2]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, -block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * coordinate_mask[mu])
#
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# block_size_1_2_1 = sizes[1]
#
# even_coords_1_2_1 = g.domain.even_odd_blocks(grid, [block_size_1_2_1 for i in range(grid.nd)], g.even).gcoor
# odd_coords_1_2_1 = g.domain.even_odd_blocks(grid, [block_size_1_2_1 for i in range(grid.nd)], g.odd).gcoor
#
# # need to sort this out because the default is [0,1], so I'll need to swap zero only if the first digit changes
#
# # need to do for second coord regardless
# for i in range(len(even_coords_1_2_1)):
#     x = even_coords_1_2_1[i].copy()
#     even_coords_1_2_1[i][1] = x[combos[2][1]]
#     even_coords_1_2_1[i][combos[2][1]] = x[1]
#
#     y = odd_coords_1_2_1[i].copy()
#     odd_coords_1_2_1[i][1] = x[combos[2][1]]
#     odd_coords_1_2_1[i][combos[2][1]] = x[1]
#
#     if combos[2][0] != 0:
# ...
#
#      # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain
#     for i in combos[3]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, -block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * coordinate_mask[mu])
#
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# block_size_1_3_0 = sizes[1]
#
# even_coords_1_3_0 = g.domain.even_odd_blocks(grid, [block_size_1_3_0 for i in range(grid.nd)], g.even).gcoor
# odd_coords_1_3_0 = g.domain.even_odd_blocks(grid, [block_size_1_3_0 for i in range(grid.nd)], g.odd).gcoor
#
# # need to sort this out because the default is [0,1], so I'll need to swap zero only if the first digit changes
#
# # need to do for second coord regardless
# for i in range(len(even_coords_1_3_0)):
#     x = even_coords_1_3_0[i].copy()
#     even_coords_1_3_0[i][1] = x[combos[3][1]]
#     even_coords_1_3_0[i][combos[3][1]] = x[1]
#
#     y = odd_coords_1_3_0[i].copy()
#     odd_coords_1_3_0[i][1] = x[combos[3][1]]
#     odd_coords_1_3_0[i][combos[3][1]] = x[1]
#
#     if combos[3][0] != 0:
#         x = even_coords_1_3_0[i].copy()
#         even_coords_1_3_0[i][0] = x[combos[3][0]]
#         even_coords_1_3_0[i][combos[3][0]] = x[0]
#
#         y = odd_coords_1_3_0[i].copy()
#         odd_coords_1_3_0[i][0] = y[combos[3][0]]
#         odd_coords_1_3_0[i][combos[3][0]] = y[0]
#
#
# even_1_3_0 = parity[0]
#
# frozen_1_3_0 = freeze_connecting_links(block_size_1_3_0, even_coords_1_3_0, odd_coords_1_3_0, even_1_3_0)
# coord_mask_1_3_0 = coordinate_mask(block_size_1_3_0, even_coords_1_3_0, odd_coords_1_3_0, even_1_3_0)
# mom_mask_1_3_0 = momentum_mask(block_size_1_3_0, even_coords_1_3_0, odd_coords_1_3_0, even_1_3_0)
#
#
# iq_1_3_0 = sympl.update_q(
#     U, log(lambda: gauge_force_coord_update_1_3_0(frozen_1_3_0, mom_mask_1_3_0, block_size_1_3_0), "gauge_force_coord_update_1_3_0")
# )
#
# ip_1_3_0 = sympl.update_p(
#     U, log(lambda: gauge_force_mom_update_1_3_0(frozen_1_3_0, coord_mask_1_3_0, block_size_1_3_0), "gauge_force_mom_update_1_3_0")
# )
#
# # integrator
# mdint_1_3_0 = sympl.leap_frog(MD_steps, iq_1_3_0, ip_1_3_0)
#
#
# def gauge_force_coord_update_1_3_1(frozen_links, momenta_mask, block_size):
#     # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain ; should be done in 2 of 3 directions, and these can al be the same
#     for i in combos[3]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * momenta_mask[mu]) # also need mask to block the other active domain!!!
#
#     #print(V)
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# def gauge_force_mom_update_1_3_1(frozen_links, coordinate_mask, block_size):
#
#      # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain
#     for i in combos[3]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, -block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * coordinate_mask[mu])
#
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# block_size_1_3_1 = sizes[1]
#
# even_coords_1_3_1 = g.domain.even_odd_blocks(grid, [block_size_1_3_1 for i in range(grid.nd)], g.even).gcoor
# odd_coords_1_3_1 = g.domain.even_odd_blocks(grid, [block_size_1_3_1 for i in range(grid.nd)], g.odd).gcoor
#
# # need to sort this out because the default is [0,1], so I'll need to swap zero only if the first digit changes
#
# # need to do for second coord regardless
# for i in range(len(even_coords_1_3_1)):
#     x = even_coords_1_3_1[i].copy()
#     even_coords_1_3_1[i][1] = x[combos[3][1]]
#     even_coords_1_3_1[i][combos[3][1]] = x[1]
#
#     y = odd_coords_1_3_1[i].copy()
#     odd_coords_1_3_1[i][1] = x[combos[3][1]]
#     odd_coords_1_3_1[i][combos[3][1]] = x[1]
#
#     if combos[3][0] != 0:
#         x = even_coords_1_3_1[i].copy()
#         even_coords_1_3_1[i][0] = x[combos[3][0]]
#         even_coords_1_3_1[i][combos[3][0]] = x[0]
#
#         y = odd_coords_1_3_1[i].copy()
#         odd_coords_1_3_1[i][0] = y[combos[3][0]]
#         odd_coords_1_3_1[i][combos[3][0]] = y[0]
#
#
# even_1_3_1 = parity[1]
#
# frozen_1_3_1 = freeze_connecting_links(block_size_1_3_1, even_coords_1_3_1, odd_coords_1_3_1, even_1_3_1)
# coord_mask_1_3_1 = coordinate_mask(block_size_1_3_1, even_coords_1_3_1, odd_coords_1_3_1, even_1_3_1)
# mom_mask_1_3_1 = momentum_mask(block_size_1_3_1, even_coords_1_3_1, odd_coords_1_3_1, even_1_3_1)
#
#
# iq_1_3_1 = sympl.update_q(
#     U, log(lambda: gauge_force_coord_update_1_3_1(frozen_1_3_1, mom_mask_1_3_1, block_size_1_3_1), "gauge_force_coord_update_1_3_1")
# )
#
# ip_1_3_1 = sympl.update_p(
#     U, log(lambda: gauge_force_mom_update_1_3_1(frozen_1_3_1, coord_mask_1_3_1, block_size_1_3_1), "gauge_force_mom_update_1_3_1")
# )
#
# # integrator
# mdint_1_3_1 = sympl.leap_frog(MD_steps, iq_1_3_1, ip_1_3_1)
#
#
# def gauge_force_coord_update_1_4_0(frozen_links, momenta_mask, block_size):
#     # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain ; should be done in 2 of 3 directions, and these can al be the same
#     for i in combos[4]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * momenta_mask[mu]) # also need mask to block the other active domain!!!
#
#     #print(V)
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# def gauge_force_mom_update_1_4_0(frozen_links, coordinate_mask, block_size):
#
#      # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain
#     for i in combos[4]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, -block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * coordinate_mask[mu])
#
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# block_size_1_4_0 = sizes[1]
#
# even_coords_1_4_0 = g.domain.even_odd_blocks(grid, [block_size_1_4_0 for i in range(grid.nd)], g.even).gcoor
# odd_coords_1_4_0 = g.domain.even_odd_blocks(grid, [block_size_1_4_0 for i in range(grid.nd)], g.odd).gcoor
#
# # need to sort this out because the default is [0,1], so I'll need to swap zero only if the first digit changes
#
# # need to do for second coord regardless
# for i in range(len(even_coords_1_4_0)):
#     x = even_coords_1_4_0[i].copy()
#     even_coords_1_4_0[i][1] = x[combos[4][1]]
#     even_coords_1_4_0[i][combos[4][1]] = x[1]
#
#     y = odd_coords_1_4_0[i].copy()
#     odd_coords_1_4_0[i][1] = x[combos[4][1]]
#     odd_coords_1_4_0[i][combos[4][1]] = x[1]
#
#     if combos[4][0] != 0:
#         x = even_coords_1_4_0[i].copy()
#         even_coords_1_4_0[i][0] = x[combos[4][0]]
#         even_coords_1_4_0[i][combos[4][0]] = x[0]
#
#         y = odd_coords_1_4_0[i].copy()
#         odd_coords_1_4_0[i][0] = y[combos[4][0]]
#         odd_coords_1_4_0[i][combos[4][0]] = y[0]
#
#
# even_1_4_0 = parity[0]
#
# frozen_1_4_0 = freeze_connecting_links(block_size_1_4_0, even_coords_1_4_0, odd_coords_1_4_0, even_1_4_0)
# coord_mask_1_4_0 = coordinate_mask(block_size_1_4_0, even_coords_1_4_0, odd_coords_1_4_0, even_1_4_0)
# mom_mask_1_4_0 = momentum_mask(block_size_1_4_0, even_coords_1_4_0, odd_coords_1_4_0, even_1_4_0)
#
#
# iq_1_4_0 = sympl.update_q(
#     U, log(lambda: gauge_force_coord_update_1_4_0(frozen_1_4_0, mom_mask_1_4_0, block_size_1_4_0), "gauge_force_coord_update_1_4_0")
# )
#
# ip_1_4_0 = sympl.update_p(
#     U, log(lambda: gauge_force_mom_update_1_4_0(frozen_1_4_0, coord_mask_1_4_0, block_size_1_4_0), "gauge_force_mom_update_1_4_0")
# )
#
# # integrator
# mdint_1_4_0 = sympl.leap_frog(MD_steps, iq_1_4_0, ip_1_4_0)
#
#
# def gauge_force_coord_update_1_4_1(frozen_links, momenta_mask, block_size):
#     # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain ; should be done in 2 of 3 directions, and these can al be the same
#     for i in combos[4]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * momenta_mask[mu]) # also need mask to block the other active domain!!!
#
#     #print(V)
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# def gauge_force_mom_update_1_4_1(frozen_links, coordinate_mask, block_size):
#
#      # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain
#     for i in combos[4]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, -block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * coordinate_mask[mu])
#
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# block_size_1_4_1 = sizes[1]
#
# even_coords_1_4_1 = g.domain.even_odd_blocks(grid, [block_size_1_4_1 for i in range(grid.nd)], g.even).gcoor
# odd_coords_1_4_1 = g.domain.even_odd_blocks(grid, [block_size_1_4_1 for i in range(grid.nd)], g.odd).gcoor
#
# # need to sort this out because the default is [0,1], so I'll need to swap zero only if the first digit changes
#
# # need to do for second coord regardless
# for i in range(len(even_coords_1_4_1)):
#     x = even_coords_1_4_1[i].copy()
#     even_coords_1_4_1[i][1] = x[combos[4][1]]
#     even_coords_1_4_1[i][combos[4][1]] = x[1]
#
#     y = odd_coords_1_4_1[i].copy()
#     odd_coords_1_4_1[i][1] = x[combos[4][1]]
#     odd_coords_1_4_1[i][combos[4][1]] = x[1]
#
#     if combos[4][0] != 0:
#         x = even_coords_1_4_1[i].copy()
#         even_coords_1_4_1[i][0] = x[combos[4][0]]
#         even_coords_1_4_1[i][combos[4][0]] = x[0]
#
#         y = odd_coords_1_4_1[i].copy()
#         odd_coords_1_4_1[i][0] = y[combos[4][0]]
#         odd_coords_1_4_1[i][combos[4][0]] = y[0]
#
#
# even_1_4_1 = parity[1]
#
# frozen_1_4_1 = freeze_connecting_links(block_size_1_4_1, even_coords_1_4_1, odd_coords_1_4_1, even_1_4_1)
# coord_mask_1_4_1 = coordinate_mask(block_size_1_4_1, even_coords_1_4_1, odd_coords_1_4_1, even_1_4_1)
# mom_mask_1_4_1 = momentum_mask(block_size_1_4_1, even_coords_1_4_1, odd_coords_1_4_1, even_1_4_1)
#
#
# iq_1_4_1 = sympl.update_q(
#     U, log(lambda: gauge_force_coord_update_1_4_1(frozen_1_4_1, mom_mask_1_4_1, block_size_1_4_1), "gauge_force_coord_update_1_4_1")
# )
#
# ip_1_4_1 = sympl.update_p(
#     U, log(lambda: gauge_force_mom_update_1_4_1(frozen_1_4_1, coord_mask_1_4_1, block_size_1_4_1), "gauge_force_mom_update_1_4_1")
# )
#
# # integrator
# mdint_1_4_1 = sympl.leap_frog(MD_steps, iq_1_4_1, ip_1_4_1)
#
#
# def gauge_force_coord_update_1_5_0(frozen_links, momenta_mask, block_size):
#     # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain ; should be done in 2 of 3 directions, and these can al be the same
#     for i in combos[5]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * momenta_mask[mu]) # also need mask to block the other active domain!!!
#
#     #print(V)
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# def gauge_force_mom_update_1_5_0(frozen_links, coordinate_mask, block_size):
#
#      # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain
#     for i in combos[5]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, -block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * coordinate_mask[mu])
#
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# block_size_1_5_0 = sizes[1]
#
# even_coords_1_5_0 = g.domain.even_odd_blocks(grid, [block_size_1_5_0 for i in range(grid.nd)], g.even).gcoor
# odd_coords_1_5_0 = g.domain.even_odd_blocks(grid, [block_size_1_5_0 for i in range(grid.nd)], g.odd).gcoor
#
# # need to sort this out because the default is [0,1], so I'll need to swap zero only if the first digit changes
#
# # need to do for second coord regardless
# for i in range(len(even_coords_1_5_0)):
#     x = even_coords_1_5_0[i].copy()
#     even_coords_1_5_0[i][1] = x[combos[5][1]]
#     even_coords_1_5_0[i][combos[5][1]] = x[1]
#
#     y = odd_coords_1_5_0[i].copy()
#     odd_coords_1_5_0[i][1] = x[combos[5][1]]
#     odd_coords_1_5_0[i][combos[5][1]] = x[1]
#
#     if combos[5][0] != 0:
#         x = even_coords_1_5_0[i].copy()
#         even_coords_1_5_0[i][0] = x[combos[5][0]]
#         even_coords_1_5_0[i][combos[5][0]] = x[0]
#
#         y = odd_coords_1_5_0[i].copy()
#         odd_coords_1_5_0[i][0] = y[combos[5][0]]
#         odd_coords_1_5_0[i][combos[5][0]] = y[0]
#
#
# even_1_5_0 = parity[0]
#
# frozen_1_5_0 = freeze_connecting_links(block_size_1_5_0, even_coords_1_5_0, odd_coords_1_5_0, even_1_5_0)
# coord_mask_1_5_0 = coordinate_mask(block_size_1_5_0, even_coords_1_5_0, odd_coords_1_5_0, even_1_5_0)
# mom_mask_1_5_0 = momentum_mask(block_size_1_5_0, even_coords_1_5_0, odd_coords_1_5_0, even_1_5_0)
#
#
# iq_1_5_0 = sympl.update_q(
#     U, log(lambda: gauge_force_coord_update_1_5_0(frozen_1_5_0, mom_mask_1_5_0, block_size_1_5_0), "gauge_force_coord_update_1_5_0")
# )
#
# ip_1_5_0 = sympl.update_p(
#     U, log(lambda: gauge_force_mom_update_1_5_0(frozen_1_5_0, coord_mask_1_5_0, block_size_1_5_0), "gauge_force_mom_update_1_5_0")
# )
#
# # integrator
# mdint_1_5_0 = sympl.leap_frog(MD_steps, iq_1_5_0, ip_1_5_0)
#
#
# def gauge_force_coord_update_1_5_1(frozen_links, momenta_mask, block_size):
#     # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain ; should be done in 2 of 3 directions, and these can al be the same
#     for i in combos[5]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * momenta_mask[mu]) # also need mask to block the other active domain!!!
#
#     #print(V)
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# def gauge_force_mom_update_1_5_1(frozen_links, coordinate_mask, block_size):
#
#      # calculate gradients
#     V = action_gauge.gradient(U, U)
#
#     # shift to other domain
#     for i in combos[5]:
#         for mu in range(grid.nd):
#             V[mu] = g.cshift(V[mu], i, -block_size)
#
#     for mu in range(grid.nd):
#         V[mu] @= g(V[mu] * frozen_links[mu] * coordinate_mask[mu])
#
#
#     x = log(lambda: V , "gauge")()
#
#     return x
#
# block_size_1_5_1 = sizes[1]
#
# even_coords_1_5_1 = g.domain.even_odd_blocks(grid, [block_size_1_5_1 for i in range(grid.nd)], g.even).gcoor
# odd_coords_1_5_1 = g.domain.even_odd_blocks(grid, [block_size_1_5_1 for i in range(grid.nd)], g.odd).gcoor
#
# # need to sort this out because the default is [0,1], so I'll need to swap zero only if the first digit changes
#
# # need to do for second coord regardless
# for i in range(len(even_coords_1_5_1)):
#     x = even_coords_1_5_1[i].copy()
#     even_coords_1_5_1[i][1] = x[combos[5][1]]
#     even_coords_1_5_1[i][combos[5][1]] = x[1]
#
#     y = odd_coords_1_5_1[i].copy()
#     odd_coords_1_5_1[i][1] = x[combos[5][1]]
#     odd_coords_1_5_1[i][combos[5][1]] = x[1]
#
#     if combos[5][0] != 0:
#         x = even_coords_1_5_1[i].copy()
#         even_coords_1_5_1[i][0] = x[combos[5][0]]
#         even_coords_1_5_1[i][combos[5][0]] = x[0]
#
#         y = odd_coords_1_5_1[i].copy()
#         odd_coords_1_5_1[i][0] = y[combos[5][0]]
#         odd_coords_1_5_1[i][combos[5][0]] = y[0]
#
#
# even_1_5_1 = parity[1]
#
# frozen_1_5_1 = freeze_connecting_links(block_size_1_5_1, even_coords_1_5_1, odd_coords_1_5_1, even_1_5_1)
# coord_mask_1_5_1 = coordinate_mask(block_size_1_5_1, even_coords_1_5_1, odd_coords_1_5_1, even_1_5_1)
# mom_mask_1_5_1 = momentum_mask(block_size_1_5_1, even_coords_1_5_1, odd_coords_1_5_1, even_1_5_1)
#
#
# iq_1_5_1 = sympl.update_q(
#     U, log(lambda: gauge_force_coord_update_1_5_1(frozen_1_5_1, mom_mask_1_5_1, block_size_1_5_1), "gauge_force_coord_update_1_5_1")
# )
#
# ip_1_5_1 = sympl.update_p(
#     U, log(lambda: gauge_force_mom_update_1_5_1(frozen_1_5_1, coord_mask_1_5_1, block_size_1_5_1), "gauge_force_mom_update_1_5_1")
# )
#
# # integrator
# mdint_1_5_1 = sympl.leap_frog(MD_steps, iq_1_5_1, ip_1_5_1)
# Exception ignored in: <function lattice.__del__ at 0x109534c20>
# Traceback (most recent call last):
#   File "/Users/ell579/Documents/Physics/lattice/gpt/lib/gpt/core/lattice.py", line 105, in __del__
#     del mem_book[self.v_obj[0]]
# KeyError: 105553172467392

# %%
def MC_run(mdint__, tau):
    V = g.copy(U)
    Ei = MC_Ham(U)
    #tau1 = tau * (np.random.randint(0,2)*2 - 1) 
    mdint__(tau)
    Ef = MC_Ham(U)
    if np.exp(- (Ef - Ei)) < np.random.uniform(0,1):
        for mu in range(4):
            U[mu] @= V[mu]
        print("REJECT", "DELTA S = ", Ef - Ei )
    
        return 0

    else:
        return 1

# %%
# untested 

code1 = []

MC_run_template = """
def MC_run_set(tau):
    a = 0
"""

code1.append(MC_run_template)

MD_step_template = """
    a += MC_run(mdint_{ff}_{ll}_{ppa}, (tau))
"""
for ff in range(len(sizes)):
    for ll in range(len(combos)):
        for ppa in range(len(parity)):
            code1.append(MD_step_template.format(ll = ll, ff = ff, ppa=ppa))

ret_template = """
    return a
"""

code1.append(ret_template)

MD_src = "\n".join(code1)
print(MD_src)
exec(MD_src, globals())
# Out:
# def MC_run_set(tau):
#     a = 0
#
#
#     a += MC_run(mdint_0_0_0, (tau))
#
#
#     a += MC_run(mdint_0_0_1, (tau))
#
#
#     a += MC_run(mdint_0_1_0, (tau))
#
#
#     a += MC_run(mdint_0_1_1, (tau))
#
#
#     a += MC_run(mdint_0_2_0, (tau))
#
#
#     a += MC_run(mdint_0_2_1, (tau))
#
#
#     a += MC_run(mdint_0_3_0, (tau))
#
#
#     a += MC_run(mdint_0_3_1, (tau))
#
#
#     a += MC_run(mdint_0_4_0, (tau))
#
#
#     a += MC_run(mdint_0_4_1, (tau))
#
#
#     a += MC_run(mdint_0_5_0, (tau))
#
#
#     a += MC_run(mdint_0_5_1, (tau))
#
#
#     a += MC_run(mdint_1_0_0, (tau))
#
#
#     a += MC_run(mdint_1_0_1, (tau))
#
#
#     a += MC_run(mdint_1_1_0, (tau))
#
#
#     a += MC_run(mdint_1_1_1, (tau))
#
#
#     a += MC_run(mdint_1_2_0, (tau))
#
#
#     a += MC_run(mdint_1_2_1, (tau))
#
#
#     a += MC_run(mdint_1_3_0, (tau))
#
#
#     a += MC_run(mdint_1_3_1, (tau))
#
#
#     a += MC_run(mdint_1_4_0, (tau))
#
#
#     a += MC_run(mdint_1_4_1, (tau))
#
#
#     a += MC_run(mdint_1_5_0, (tau))
#
#
#     a += MC_run(mdint_1_5_1, (tau))
#
#
#     return a

# %%
dwfeMC2 = []
TPQ_mc = []
eps = 0.05

trajectories = 100

ergod = 1
history = 0

for i in range(trajectories):
    if i == 0:
        U_wf = g.copy(U)
        for l in range(160): # t = 4
            U_wf = g.qcd.gauge.smear.wilson_flow(U_wf, epsilon=eps)
                
        dwfeMC2.append( g.qcd.gauge.energy_density(U_wf))
        TPQ_mc.append( g.qcd.gauge.topological_charge(U_wf) )
    
    for k in range(ergod):
        hmc(tau, mom)
        print("HMC ", g.qcd.gauge.plaquette(U))
    
    history += MC_run_set(tau) # 12 hmc trajectories of force evaluation
    print("MC plaquette = ", g.qcd.gauge.plaquette(U))
    U_wf = g.copy(U)
    for l in range(160): # t = 4
        U_wf = g.qcd.gauge.smear.wilson_flow(U_wf, epsilon=eps)
            
    wff = g.qcd.gauge.energy_density(U_wf)
    Qf = g.qcd.gauge.topological_charge(U_wf)
    TPQ_mc.append( Qf )
        
    dwfeMC2.append(wff )
    
    print("Procedure ", i)
    print("WFE = ", wff)
    print("Q = ", Qf)

print(history / (trajectories * 4))
# Out:
# HMC  0.6704424730032357
# REJECT DELTA S =  0.42815006853925297
# MC plaquette =  0.670440272172069
# Procedure  0
# WFE =  (0.02100393502108122+2.760575014509216e-37j)
# Q =  -0.8962951723205856
# HMC  0.6713836041064855
# REJECT DELTA S =  0.06317112228134647
# REJECT DELTA S =  0.07870629816898145
# MC plaquette =  0.6713805825895786
# Procedure  1
# WFE =  (0.02040294359863094-1.93290760538532e-37j)
# Q =  -0.8912863934845919
# HMC  0.6725798358309608
# REJECT DELTA S =  0.18031749900546856
# REJECT DELTA S =  0.8656467579639866
# REJECT DELTA S =  0.49655020784121007
# REJECT DELTA S =  0.39588459520746255
# REJECT DELTA S =  0.4680645815751632
# REJECT DELTA S =  0.23059111887414474
# REJECT DELTA S =  0.29764395907113794
# MC plaquette =  0.6706813171319085
# Procedure  99
# WFE =  (0.00043731543435023104+2.0806479598294884e-39j)
# Q =  -3.4565453766185646e-06
# 5.5075

# %%
dwfeHMC2 = []
TPQ_hmc = []
eps = 0.05

trajectories = 100

ergod = 13
history = 0

for i in range(trajectories):
    if i == 0:
        U_wf = g.copy(U)
        for l in range(160): # t = 4
            U_wf = g.qcd.gauge.smear.wilson_flow(U_wf, epsilon=eps)
                
        dwfeHMC2.append( g.qcd.gauge.energy_density(U_wf))
        TPQ_hmc.append( g.qcd.gauge.topological_charge(U_wf) )
    
    for k in range(ergod):
        hmc(tau, mom)
        print("HMC ", g.qcd.gauge.plaquette(U))
    
    #history += MC_run_set(tau) # 12 hmc trajectories of force evaluation
    #print("MC plaquette = ", g.qcd.gauge.plaquette(U))
    
    U_wf = g.copy(U)
    for l in range(160): # t = 4
        U_wf = g.qcd.gauge.smear.wilson_flow(U_wf, epsilon=eps)
            
    wff = g.qcd.gauge.energy_density(U_wf)
    Qf = g.qcd.gauge.topological_charge(U_wf)
    TPQ_hmc.append( Qf )
        
    dwfeHMC2.append(wff )
    
    print("Procedure ", i)
    print("WFE = ", wff)
    print("Q = ", Qf)

print(history / (trajectories * 4))
# Out:
# HMC  0.6709225284153025
# HMC  0.6716443581634154
# HMC  0.672108438345192
# HMC  0.6725792232762365
# HMC  0.6732193223032055
# HMC  0.6704829508310284
# HMC  0.6732489876109424
# HMC  0.6730660023456463
# HMC  0.6712702807427532
# HMC  0.6712702807427532
# HMC  0.6726695588473485
# HMC  0.6739412583799959
# HMC  0.6749266639586146
# Procedure  0
# WFE =  (0.0006813405656333944+6.37108754596064e-40j)
# Q =  -1.510105417596783e-05
# HMC  0.6726342840141982
# HMC  0.6704807519370148
# HMC  0.6715275464209675
# HMC  0.6715275464209675
# HMC  0.6700294004209139
# HMC  0.6697259664609053
# HMC  0.6713152716827563
# HMC  0.6725540044444508
# HMC  0.6722471165316749
# HMC  0.6736670886223285
# HMC  0.6727033070513179
# HMC  0.6727209528239034
# HMC  0.6722665071364505
# Procedure  1
# WFE =  (0.0005067068883248901-2.7550648847397363e-40j)
# Q =  4.264303208496849e-06
# HMC  0.6724060756478427
# HMC  0.673419921083216
# HMC  0.6708016084807705
# HMC  0.6709493139037837
# HMC  0.6677373025640811
# HMC  0.6681043547094361
# HMC  0.6672369460886277
# HMC  0.6664635783131184
# HMC  0.6692894378012048
# HMC  0.6682998547884592
# HMC  0.669637926188043
# HMC  0.6703783880215402
# HMC  0.6690879427521348
# Procedure  2
# WFE =  (0.00032646108118823447+1.3201352572711237e-40j)
# Q =  -2.5523601830740404e-06
# HMC  0.67018978251192
# HMC  0.667894273521518
# HMC  0.6689779411956627
# HMC  0.6713226877947106
# HMC  0.6715625861362597
# HMC  0.6720886399145805
# HMC  0.6724865584918848
# HMC  0.6735059329853388
# HMC  0.6741171411393702
# HMC  0.6725492743893194
# HMC  0.6717455704380485
# HMC  0.672155211966586
# HMC  0.6730255626782928
# HMC  0.6733712979827943
# HMC  0.670826069879307
# HMC  0.6713200483556574
# HMC  0.6711439777153251
# HMC  0.6713628972415372
# HMC  0.6715694007237016
# Procedure  95
# WFE =  (0.0004523004226497613+1.5698130124506623e-39j)
# Q =  -1.8485124475286385e-06
# HMC  0.671056863018233
# HMC  0.6699588515718339
# HMC  0.6705753822270034
# HMC  0.6707799936533392
# HMC  0.6697535174497324
# HMC  0.6689739337875337
# HMC  0.6689739337875337
# HMC  0.6689739337875337
# HMC  0.6715841716324068
# HMC  0.6719907220104268
# HMC  0.6714813994734908
# HMC  0.6698538245009201
# HMC  0.6709922938563341
# Procedure  96
# WFE =  (0.0006084201558430418-2.049079508025179e-39j)
# Q =  1.2683099708758211e-05
# HMC  0.6723589556338133
# HMC  0.6729014361627184
# HMC  0.6734010930515165
# HMC  0.6741746220283228
# HMC  0.6758890651702621
# HMC  0.6746291834744947
# HMC  0.6757327962357565
# HMC  0.6726020695946963
# HMC  0.6740301092518437
# HMC  0.6738368386961628
# HMC  0.6717442399326393
# HMC  0.6719471038189403
# HMC  0.6719471038189403
# Procedure  97
# WFE =  (0.0004040450641407303+1.6071211827648462e-40j)
# Q =  3.325442510154475e-06
# HMC  0.6710872628394515
# HMC  0.6696908553075048
# HMC  0.6714879907909367
# HMC  0.6702560478319283
# HMC  0.6691687382031118
# HMC  0.6690565054226757
# HMC  0.669137838179572
# HMC  0.6698656610289248
# HMC  0.6720794205783016
# HMC  0.6715230882861122
# HMC  0.6726872785726788
# HMC  0.6733132226634667
# HMC  0.6729072563379431
# Procedure  98
# WFE =  (0.0005035196101324981-6.543279101256874e-40j)
# Q =  4.000898353377523e-06
# HMC  0.6727611477517397
# HMC  0.6720023240230742
# HMC  0.6714851162300074
# HMC  0.6724056536404331
# HMC  0.6732218858896851
# HMC  0.6725463007348961
# HMC  0.6722149286855462
# HMC  0.6728147618872619
# HMC  0.6715302126953211
# HMC  0.6713174949857499
# HMC  0.6713174949857499
# HMC  0.6723764600676773
# HMC  0.6713759687065687
# Procedure  99
# WFE =  (0.0005030863106045016-1.0288445428949953e-39j)
# Q =  2.411661342019957e-06
# 0.0

# %%
MC = autocorrelation2(dwfeMC2[20:], 1, 20, 1)
HMC = autocorrelation2(dwfeHMC2[20:], 1, 20, 1)


plt.title("E(8) vs combined MD trajectories", size=20 )
plt.ylabel("autocorrelation E(16)", size=20)
plt.xlabel("HMC (HMC  + MC)  trajs",size=20)
plt.errorbar(np.arange(len(MC[0])), MC[0], MC[1], color='black', label='MC', capsize=5, linestyle=':') # MC
plt.errorbar(np.arange(len(HMC[0])), HMC[0], HMC[1], color= 'grey', label="HMC", capsize=5) #HMC
plt.axhline(y=0, color='red', linestyle='--')
plt.legend()
#plt.savefig("2D_100_E16_AC.pdf")

# %%
plt.plot(dwfeMC2[20:])
plt.plot(dwfeHMC2[20:])

# %%
plt.plot(TPQ_mc)
plt.plot(TPQ_hmc)
